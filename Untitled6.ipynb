# %%
import pandas as pd
import numpy as np
np.random.seed(seed=0)

# %%
data=pd.read_csv('mergedf.csv')

# %%
print(len(data))
# Out:
# 37664

# %%
data.head()
# Out:
#    Unnamed: 0   카테고리                              제목     참여인원      청원 시작일  \
# 0           0  안전/환경  텔레그램 n번방 용의자 신상공개 및 포토라인 세워주세요  2715626  2020-03-18
# 1           1  안전/환경     텔레그램 n번방 가입자 전원의 신상공개를 원합니다  2026252  2020-03-20
# 2           2   정치개혁                  자유 한국당 정당해산 청원  1831900  2019-04-22
# 3           3     기타               문재인 대통령님을 응원 합니다!  1504597  2020-02-26
# 4           4   정치개혁              문재인 대통령 탄핵을 촉구합니다.  1469023  2020-02-04
#
#        청원 마감일    연도                                                 내용
# 0  2020-04-17  2020  오늘 검거되었다고 합니다\n타인의 수치심과 어린 학생들을\n지옥으로 몰아넣은 가해자...
# 1  2020-04-19  2020  안녕하세요,\n\n텔레그램 n번방에 대한 수사가 진행되고 일부의 용의자가 검거되어 ...
# 2  2019-05-22  2019  민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원으...
# 3  2020-03-27  2020  코로나 바이러스19로 인해 대한민국 모든 국민이 힘든 시기에 있습니다. 하지만 국민...
# 4  2020-03-05  2020  국민의 한 사람으로서 문재인 대통령의 탄핵을 촉구합니다. \n\n이번 우한 폐렴(신...

# %%
data=data[['제목','내용']]

# %%
data
# Out:
#                                                       제목  \
# 0                         텔레그램 n번방 용의자 신상공개 및 포토라인 세워주세요
# 1                            텔레그램 n번방 가입자 전원의 신상공개를 원합니다
# 2                                         자유 한국당 정당해산 청원
# 3                                      문재인 대통령님을 응원 합니다!
# 4                                     문재인 대통령 탄핵을 촉구합니다.
# ...                                                  ...
# 37659                              광주 폭력 사태 또한 경찰 공권력 문제
# 37660                           전북 신안군에 대한 철저한 조사를 촉구합니다
# 37661                                       사이비교주에 대한 처벌
# 37662                                    국회를 해산하고 다시 뽑자.
# 37663  전국 고등 법원에 상고심 법원(법리+사실심  겸용) 신설 및  공수처 설치법 긴급 ...
#
#                                                       내용
# 0      오늘 검거되었다고 합니다\n타인의 수치심과 어린 학생들을\n지옥으로 몰아넣은 가해자...
# 1      안녕하세요,\n\n텔레그램 n번방에 대한 수사가 진행되고 일부의 용의자가 검거되어 ...
# 2      민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원으...
# 3      코로나 바이러스19로 인해 대한민국 모든 국민이 힘든 시기에 있습니다. 하지만 국민...
# 4      국민의 한 사람으로서 문재인 대통령의 탄핵을 촉구합니다. \n\n이번 우한 폐렴(신...
# ...                                                  ...
# 37659  안녕하세요.\n\n다름이 아니라 이번 광주 폭력사태를 보고 난 후 한 사람으로 써 ...
# 37660  지난 sbs 그것이 알고싶다와 관련하여 \n전북 신안군에 대한 대대적인 수사를 요청...
# 37661  붓다를 이루어 중생들의 삼세를 바라보며 빙의된 귀신을 떼어 내어 준다며 \n금전을 ...
# 37662  너무나도 어처구니 없고 국민에게 하루종일 스트레스주는 국회의원이 너무  많아 스트레...
# 37663  ## 전국 고등 법원에 상고심 법원 신설 및  공수처 설치법 긴급 법안 통과 조치 ...
#
# [37664 rows x 2 columns]

# %%
data.sample(100)
# Out:
#                                                 제목  \
# 1067     한국 김산업의 일본 종속화를 막아주세요 (한국 김산업 다 망하게 생겼어요)
# 21095             서울도시철도(지하철) 종로3가역에 전태일역을 병기해 주세요
# 11277     한국어 음성더빙을 하지 않는 공영방송 KBS 결정권자를 해고해 주십시오.
# 36839                              가정용 전기요금 누진제 폐지
# 32639  금수저만을 위한 신혼부부특별공급 개선해주세요. 2030세대에게 희망을 주세요.
# ...                                            ...
# 10261      한국공항공사 소방직 정규직 전환시험 모든 공공부문 비정규직의 미래!!!
# 30868          인천 다문화 가정중학생 살인범들 마스크 벗고 얼굴 보게해주십시요
# 5745                          친일부일민족반역자 척결을 다시합시다.
# 30735                     분산된 대한항공관련 청원을 하나로 모아주세요
# 20168       서울공연예술고등학교의 특목고 지정 취소(일반고 전환)을 재고해주세요.
#
#                                                       내용
# 1067   1.\t일본의 김 산업 1위 업체인 小淺(고아사)가 부산.진해경제 자유구역 남문지구...
# 21095  안녕하세요. 철도노동자 김**입니다.\n\n내년이면 “근로기준법을 준수하라. 우리는...
# 11277  2018년 9월 24일 KBS2TV를 통해 방송되는 추석특집 외화 "가디언즈 오브 ...
# 36839  아시다시피 강남등등 길거리에 다니다보면 1층 사업장들은 문을 활짝 열어놓고 에어컨 ...
# 32639  안녕하세요 돌아기 키우고 있는 20대후반 엄마입니다. 제가 청원을 하게 된 이유는 ...
# ...                                                  ...
# 10261  안녕하십니까 저는 현재 공항 소방대에서 재직 중인 대원입니다.\n\n비정규직 공항 ...
# 30868  사람을 지속적인 괴롭힘과  고통속에서 아파트 옥상으로끌고가 패딩잠바까지 뺏고  두들...
# 5745   해방후 친일부일민족반역자 척결을 위한 반민특위가 시작하자마자 친일경찰에 의해 습격되...
# 30735  악덕기업 한진그룹(대한항공)에 관한 청원이 분산되어 10페이지 분량입니다.  20만...
# 20168  안녕하세요. 중학교 3학년 동생을 둔 학생입니다. 우선 국민 청원을 올리게 된 요점...
#
# [100 rows x 2 columns]

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['제목'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['내용'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 37205
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 37562

# %%
data.drop_duplicates(subset=['제목'], inplace=True)
print("전체 샘플수 :", len(data))
# Out:
# 전체 샘플수 : 37205

# %%
print(data.isnull().sum())
# Out:
# 제목    0
# 내용    4
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 37201

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = "않습니다 왜냐하면 되기 을 를 주세요"
print('개수',len(stop_words))
# Out:
# 개수 20

# %%
def preprocess_sentence(sentence, remove_stopwords = True):
    #sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열  제거 Ex) my husband (and myself) for => my husband for
    #sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stop_words if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
def preprocessing(sentence):
    total_review = ''
    #인풋리뷰
    for idx in range(len(sentence)):
        r = sentence[idx]
        #하나의 리뷰에서 문장 단위로 자르기
        for sentence in kkma.sentences(r):
            sentence = re.sub('([a-zA-Z])','',sentence)
            sentence = re.sub('[ㄱ-ㅎㅏ-ㅣ]+','',sentence)
            sentence = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','',sentence)
            if len(sentence) == 0:
                continue
            if len(sentence) < 198:
                sentence = spacing(sentence)
            sentence += '. '
            total_review += sentence
    return total_review

# %%
temp_text = '민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원'
temp_summary = '자유 한국당 정당해산 청원'
print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, 0))
# Out:
# 민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원
# 자유 한국당 정당해산 청원

# %%
clean_text = []
for s in data['내용']:
    clean_text.append(preprocess_sentence(s))
clean_text[:5]
# Out:
# ['오늘 검거되었다고 합니다 타인의 수치심과 어린 학생들을 지옥으로 몰아넣은 가해자를 포토라인에 세워주세요 절대로 모자나 마스크로 얼굴을 가리지 말아주십시오 동시접속 25만명에 어린학생의 성기에 애벌레를 집어넣는걸 150만원이나 주고 관전하는 대한민국 남자들의 삐뚤어진 성관념에 경종을 울려주십시오 피해자를 겁박하여 가족앞에서 유사성행위를 하고.. 이게 악마가 아니면 뭐가 악마인가요?? 반드시 포토라인에 세워야 합니다 얼굴 그대로!! 타인의 수치심을 가벼이 여기는자에게 인권이란 단어는 사치입니다 언제까지 두고 보시려고 하십니까? 이런 나라에서 딸자식을 키우라는건 말이 안됩니다',
#  '안녕하세요, 텔레그램 n번방에 대한 수사가 진행되고 일부의 용의자가 검거되어 다행입니다. 이번 텔레그램을 통한 미성년 특히 아동에 대한 성범죄는 절대 재발해선 안될 경악스럽고 추악한 범죄임에 의심의 여지가 없습니다. 그러나 범죄는 대한민국에서 반드시 재발할 것입니다. 방에 가입된 26만의 구매자가 아무 처벌도 받지 않기 때문입니다. 관리자, 공급자만 백날 처벌해봤자 소용 없습니다. 물론 관리자나 공급자에 대한 처벌도 제대로 이루어지지 않겠지만요. 이러한 형태의 범죄는, 수요자가 있고. 수요자의 구매 행위에 대한 처벌이 없는 반드시 재발합니다. 또다시 희생양들이 생겨납니다. 미국은 아동 포르노물을 소지하기만 해도 처벌받습니다. 반면 우리나라는 어떤지 묻고 싶습니다. 부끄러운 현실입니다. 아동을 강간하고 살인 미수에 이르러도 고작 12년, 중형이래봐야 3년, 5년이 고작인 나라입니다. 정도면, 대한민국에서 아동 성범죄 안저지르는 사람이 바보일 지경입니다. 여기서 술먹었다고 감형, 초범이라고 감형.. 아동 성범죄가 없어지길 바라는게 말이 안되지 않습니까? 과연 대한민국은 아동 성범죄를 근절하고자 하는 의지를 가진 나라인가요? 텔레그램 방에 있었던 가입자 전원 모두가 성범죄자입니다. 어린 여아들을 상대로 잔혹한 성범죄의 현장을 보며 방관은 것은 물론이고 그런 범죄 컨텐츠를 보며 흥분하고, 동조하고, 나도 범죄를 저지르고 싶다며 설레어한 역겨운 가입자 모두가 성범죄자입니다. 잠재적 성범죄자가 아닌 그냥 성범죄자들입니다. 그러나 그들은 처벌받지 않겠지요. 딸을 포함한 땅의 여자아이들은 n번방의 가입자들과 섞여서 살아가야 합니다. 방금까지 엽기적이고 변태적이고 잔혹하기 짝이없는 성범죄 영상을 보며 동조하고 이입하고 동일한 범죄를 꿈꾸던 변태 싸이코패쓰들이, 누군지 모른채 주변에 널려있습니다. 소름이 끼치지만 저희에겐 방법이 없습니다. 그러니, 처벌하지 않으실 거라면 그들의 신상이라도 알려주십시오. 저는 알아야겠습니다. 나라가 아이들을 아동 성범죄자들로부터 지켜주지 않을 거라면, 알아서 피할수라도 있게, n번방 가입자 전원의 신상을 낱낱히 공개해 주십시오. 어디에 살고 어느 직장에 다니며 나이 몇살의 어떻게 생긴 누가, n번방에 참여하였는지, 26만명의 범죄자 명단을 공개해 주시기 바랍니다. 마지막으로 이러한 반인륜적이고 패륜적인 범죄 앞에서, 범죄자 인권 보호가 명단 공개의 걸림돌이 되지는 않도록 주실 것을 간곡히 부탁드립니다. 이미 그들은 방에서 피해자들의 신상정보와 얼굴을 모두 공개한 채로 반인권적인 범죄를 저지르고 성범죄 현장을 영상으로 중계하고 시청한 이들입니다. 읽어주셔서 감사합니다.',
#  '민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원으로 구성 되었음에도 걸핏하면 장왜투쟁과 정부의 입법을 발목잡기를 하고 소방에관한 예산을 삭감하여 국민의 안전을 심각하게하며 정부가 국민을 위한 정책을 시행하지못하도록 사사건건 방해를 하고있습니다 의원들의 국민에 대한 막말도 도를 넘치고있으며 대한민국 의원인지 일본의 의원인지 모를 나경원 원내 대표도 국회의원의 자격이 없다고 봅니다 정부에서도 그간 자유한국당의 잘못된것을 철저히 조사기록하여 정당해산 청구를 하여주십시요 자유한국당에서 이미 통진당. 정당해산을한 판례가 있기에 반드시 자유한국당을 정당해산 시켜서 나라가 바로 설수있기를 간곡히 청원합니다',
#  '코로나 바이러스19로 인해 대한민국 모든 국민이 힘든 시기에 있습니다. 하지만 국민건강을 위해 대통령님을 비롯한 대한민국 정부 부처의 모든 분들이 밤낮 없이 바이러스 퇴치에 온갖 힘을 쏟고 계십니다. 하지만 신천치 라는 생각치도 못한 사이비 종교의 무분별한 바이러스 확산으로 인해,코로나 19청정지역이었던 대한민국인 일주일 사이 급속도록 확진자들이 불어 나고 있으며,국민들 모두 힘들어 하는 상황 까지 오게 되었습니다. 정부의 협조 요청에도 묵묵부담으로 일삼고 있는 사이비 종교 신천지. 이러한 조건 속에서도 대통령님은 밤낮없이 오직 국민들의 안전을 위해 노력 하고 계시며, 신천지 바이러스의 근원지가 되어 버린 대구&amp;경북 지역을 위해 무척이나 애쓰시고 계십니다. 수많은 가짜 뉴스가 대통령님 질병관리본부 그리고 대한민국 부처을 힘들게 하고 있지만 수많은 대한민국 국민들은 “문재인 대통령”님을 믿고 응원하고 있습니다. 어려운 시기는 대통령님과 함께 반드시 이겨낼 것이며, 대한민국 국민 대다수는 정부에 대한 신뢰로 함께 극복해나갈 거라 믿어 의심치 않습니다. 문재인 대통령님 언제나 응원 합니다!! 문재인 대통령님이 있는 대한민국은 반드시 어려운 상황을 극복 해나갈 것입니다.!!',
#  "국민의 사람으로서 문재인 대통령의 탄핵을 촉구합니다. 이번 우한 폐렴(신종 코로나 바이러스)사태에 있어 문재인 대통령의 대처를 보면 수록, 대한민국의 대통령이 아닌 중국의 대통령을 보는 합니다. 국내에서는 마스크가 가격이 10배 이상 폭등하고 품절상태가 지속되어 마스크 품귀현상으로 국민들이 마스크를 구입하기도 어려운 대통령은 300만개의 마스크를 중국에 지원하였으며 마스크 가격 폭등에 대한 어떠한 조치도 내어놓고 있지 않습니다. 또한 전세계적으로 62개국이 중국인 입국금지, 중국 경유한 외국인에 대한 입국 금지 강력한 제재조치를 행했음에도 정부는 국제법을 운운하다가 전세계 수많은 나라들이 입국금지 조치를 내어놓자 눈치게임하듯 이제서야 눈치보며 내놓은 대책이라는 것이 '후베이성을 2주내 방문한 외국인 4일부터 입국 전면 금지'라는 대책이라니! 도대체 말이 되지 않습니다. 중국 전역이 아니요 이미 봉쇄, 폐쇄중인 후베이성을 방문한 외국인 입국금지라니, 중국 전역에서 환자가 나오고 있는 시점에 도저히 받아 들일 없습니다. 이미 우한지역 봉쇄 직전 빠져나간 중국인이 500만명이 넘는데, 이미 봉쇄한 후베이성을 방문한 외국인에 대한 제한만 둔다면, 외의 지역에 있는 모든 중국인들에게는 계속 한국을 드나들 있도록 허락하고 자유로이 개방한 것과 마찬가지입니다. 현재 국내 확진자가 늘어가고, 확진자가 하나도 없는 뉴질랜드에서조차 강력한 입국금지 조치를 취하고 있음에도 우리나라는 허울뿐인 입국금지 대책만 내어놓고 실질적인 대책을 전혀 내어놓지 않고 있습니다. 현재도 하루에 2만명의 중국인들이 계속해서 대한민국으로 입국하고 있습니다. 대한민국 대통령으로서 무엇보다 중요하게 생각해야 하는 것은 '자국민 보호' 아닐까요? 정말 자국민을 생각했다면 중국 모든 지역을 대상으로 입국금지 했어야 합니다. 더이상은 지켜만 없습니다. 문재인 대통령을 우리나라 대통령이라고 생각하기 어렵습니다. 탄핵을 촉구합니다."]

# %%
clean_summary = []
for s in data['제목']:
    clean_summary.append(preprocess_sentence(s, 0))
clean_summary[:5]
# Out:
# ['텔레그램 n번방 용의자 신상공개 포토라인 세워주세요',
#  '텔레그램 n번방 가입자 전원의 신상공개를 원합니다',
#  '자유 한국당 정당해산 청원',
#  '문재인 대통령님을 응원 합니다!',
#  '문재인 대통령 탄핵을 촉구합니다.']

# %%
data['내용'] = clean_text
data['제목'] = clean_summary

# %%
data.replace('', np.nan, inplace=True)
print(data.isnull().sum())
# Out:
# 제목    1
# 내용    2
# dtype: int64

# %%
data.dropna(axis = 0, inplace = True)
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 37198

# %%
import matplotlib.pyplot as plt
text_len = [len(s.split()) for s in data['내용']]
summary_len = [len(s.split()) for s in data['제목']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('Summary')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 8303
# 텍스트의 평균 길이 : 236.6629119845153
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 62
# 요약의 평균 길이 : 6.262057099844077

# %%
text_max_len = 200
summary_max_len = 10

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s.split()) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['내용'])
# Out:
# 전체 샘플 중 길이가 200 이하인 샘플의 비율: 0.6137695575030916

# %%
below_threshold_len(summary_max_len, data['제목'])
# Out:
# 전체 샘플 중 길이가 10 이하인 샘플의 비율: 0.9013387816549276

# %%
data = data[data['내용'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['제목'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 21461

# %%
data.head()
# Out:
#                              제목  \
# 0  텔레그램 n번방 용의자 신상공개 포토라인 세워주세요
# 2                자유 한국당 정당해산 청원
# 3             문재인 대통령님을 응원 합니다!
# 6   강서구 피시방 살인 사건. 심신미약 피의자입니다.
# 7    렌트카 훔쳐 사망사고를 10대 엄중 처벌해주세요
#
#                                                   내용
# 0  오늘 검거되었다고 합니다 타인의 수치심과 어린 학생들을 지옥으로 몰아넣은 가해자를 ...
# 2  민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원으...
# 3  코로나 바이러스19로 인해 대한민국 모든 국민이 힘든 시기에 있습니다. 하지만 국민...
# 6  2018년 10월 14일 엊그제 일어난 강서구 피시방 살인사건에 대한 청원입니다. ...
# 7  29일 오전 0시 1분쯤 대전 동구의 네거리에서 훔친 렌터카를 몰던 10대 청소년 ...

# %%
data['decoder_input'] = data['제목'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['제목'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                              제목  \
# 0  텔레그램 n번방 용의자 신상공개 포토라인 세워주세요
# 2                자유 한국당 정당해산 청원
# 3             문재인 대통령님을 응원 합니다!
# 6   강서구 피시방 살인 사건. 심신미약 피의자입니다.
# 7    렌트카 훔쳐 사망사고를 10대 엄중 처벌해주세요
#
#                                                   내용  \
# 0  오늘 검거되었다고 합니다 타인의 수치심과 어린 학생들을 지옥으로 몰아넣은 가해자를 ...
# 2  민주당과 정부에 간곡히 청원합니다 자유한국당은 국민의 막대한 세비를 받는 국회의원으...
# 3  코로나 바이러스19로 인해 대한민국 모든 국민이 힘든 시기에 있습니다. 하지만 국민...
# 6  2018년 10월 14일 엊그제 일어난 강서구 피시방 살인사건에 대한 청원입니다. ...
# 7  29일 오전 0시 1분쯤 대전 동구의 네거리에서 훔친 렌터카를 몰던 10대 청소년 ...
#
#                            decoder_input  \
# 0  sostoken 텔레그램 n번방 용의자 신상공개 포토라인 세워주세요
# 2                sostoken 자유 한국당 정당해산 청원
# 3             sostoken 문재인 대통령님을 응원 합니다!
# 6   sostoken 강서구 피시방 살인 사건. 심신미약 피의자입니다.
# 7    sostoken 렌트카 훔쳐 사망사고를 10대 엄중 처벌해주세요
#
#                           decoder_target
# 0  텔레그램 n번방 용의자 신상공개 포토라인 세워주세요 eostoken
# 2                자유 한국당 정당해산 청원 eostoken
# 3             문재인 대통령님을 응원 합니다! eostoken
# 6   강서구 피시방 살인 사건. 심신미약 피의자입니다. eostoken
# 7    렌트카 훔쳐 사망사고를 10대 엄중 처벌해주세요 eostoken

# %%
encoder_input = np.array(data['내용'])
decoder_input = np.array(data['decoder_input'])
decoder_target = np.array(data['decoder_target'])

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [19576  3693 21269 ...  9624  4854 13490]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :',n_of_val)
# Out:
# 테스트 데이터의 수 : 4292

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 17169
# 훈련 레이블의 개수 : 17169
# 테스트 데이터의 개수 : 4292
# 테스트 레이블의 개수 : 4292

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request

src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(encoder_input_train)

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 365633
# 등장 빈도가 6번 이하인 희귀 단어의 수: 338657
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 26976
# 단어 집합에서 희귀 단어의 비율: 92.62211014870103
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 32.208373124832356

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words = src_vocab) 
src_tokenizer.fit_on_texts(encoder_input_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# %%
print(encoder_input_train[:3])
# Out:
# [[26, 2055, 5, 1415, 15, 7227, 1415, 15, 1416, 1401, 407, 1920, 7227, 5609, 3671, 1416, 4483, 3754, 88, 624, 3], [6705, 1329, 1016, 18, 6705, 5273, 5610, 1248, 3, 6451, 765, 2113, 3319], [66, 294, 3612, 92, 4484, 423, 5611, 129, 3922, 4255, 5807, 1142, 1569, 136, 4981, 3053, 4134, 1859, 9, 3849, 396, 155, 92, 5612, 3923, 823, 4981, 3923, 824, 3392, 4981, 3923, 3114, 92, 1001, 2490, 259, 7864, 482, 4600, 108, 92, 4981, 3923, 7, 1357, 1569, 7514, 63, 92, 54, 595, 9, 138]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 37087
# 등장 빈도가 5번 이하인 희귀 단어의 수: 34900
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2187
# 단어 집합에서 희귀 단어의 비율: 94.10305497883355
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 43.70134761864903

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words = tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# %%
print(decoder_input_train[:5])
# Out:
# [[1], [1, 5], [1, 189], [1, 1549, 3], [1, 1162, 1340, 835, 24, 217]]

# %%
print(decoder_target_train[:5])
# Out:
# [[2], [5, 2], [189, 2], [1549, 3, 2], [1162, 1340, 835, 24, 217, 2]]

# %%
#빈 샘플 확인
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

# %%
print('삭제할 훈련 데이터의 개수 :',len(drop_train))
print('삭제할 테스트 데이터의 개수 :',len(drop_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 1994
# 삭제할 테스트 데이터의 개수 : 524

# %%
#빈 샘플 삭제 후
encoder_input_train = np.delete(encoder_input_train, drop_train, axis=0)
decoder_input_train = np.delete(decoder_input_train, drop_train, axis=0)
decoder_target_train = np.delete(decoder_target_train, drop_train, axis=0)

encoder_input_test = np.delete(encoder_input_test, drop_test, axis=0)
decoder_input_test = np.delete(decoder_input_test, drop_test, axis=0)
decoder_target_test = np.delete(decoder_target_test, drop_test, axis=0)

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 15175
# 훈련 레이블의 개수 : 15175
# 테스트 데이터의 개수 : 3768
# 테스트 레이블의 개수 : 3768
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen = text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen = text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen = summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen = summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen = summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen = summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 200, 128)     1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 200, 256), ( 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 200, 256), ( 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 200, 256), ( 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 2000)   514000      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,633,104
# Trainable params: 3,633,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/thushv89/attention_keras/master/src/layers/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 200, 128)     1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 200, 256), ( 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 200, 256), ( 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 200, 256), ( 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 256),  131328      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 2000)   1026000     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,276,432
# Trainable params: 4,276,432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)
history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
          validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
          batch_size = 256, callbacks=[es], epochs = 50)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 762s 13s/step - loss: 2.5786 - val_loss: 2.0369
# Epoch 2/50
# 60/60 [==============================] - 743s 12s/step - loss: 2.0829 - val_loss: 1.9149
# Epoch 3/50
# 40/60 [===================>..........] - ETA: 4:01 - loss: 2.0059
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-ee4ec6f87319> in <module>
#       1 es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)
# ----> 2 history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
#       3           validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
#       4           batch_size = 256, callbacks=[es], epochs = 50)
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
#encoder 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# %%
# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if(i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(500, 1000):
    print("원문 : ",seq2text(encoder_input_test[i]))
    print("실제 요약문 :",seq2summary(decoder_input_test[i]))
    print("예측 요약문 :",decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 :  의혹 철저히 조사해서 낱낱이 조사해서 국민적 의혹을 만약 파면하고 엄벌에 청원합니다 서울 당장 윤석열 위증 https www youtube com watch v 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 검찰총장
# 예측 요약문 :  국회의원
#
#
# 원문 :  조선일보 막말 심지어 과연 어떤 환경에서 정말 화가납니다 어디 조선 없고 언론의 이런 정말 이게 정상적인 부디 제발 갑질과 그냥 시간이 지나면 제발 해주세요
# 실제 요약문 : 조선일보 언론사 진정
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나19로 많은 국민들이 고통을 받고 있습니다 국민들은 물론이고 되길 기다리고 있습니다 그럼에도 불구하고 신천지는 가면을 쓰고 국민의 안전을 위협하고 있습니다 이에 신천지 명단을 공개하고 전체 대상으로 이상 코로나19의 확산을 막고 국민의 안전을 것을 청원합니다
# 실제 요약문 : 신천지 교인 전체를 주십시요
# 예측 요약문 :  국회의원
#
#
# 원문 :  국가 이용하여 마스크를 삼아 마스크를 보내지 않고 돈을
# 실제 요약문 : 인한 마스크 엄중 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국 조국 품으로 좋겠습니다 대한민국 정부 나서서 지원 해주세요 대한민국 사람 으로써 저는 대한민국 품으로 좋겠습니다
# 실제 요약문 : 그랜드캐니언 우리 도와주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  존재합니다 근데 무슨 국민건강 한다는게 말입니까 뭡니까 그게 국민건강 아닙니까 차라리 세금 하십시오 국민건강 같은 핑계
# 실제 요약문 : 인상 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대통령님 약속을 지켜주세요 5년 약속을 지켜주세요
# 실제 요약문 : 10년 개선해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  의원 체포동의안 관련하여 의원의 명단을 것을 그들을 일명 으로 반드시 처단해야 것을 요구합니다 그리고 국가와 국민을 의무를 저버린 국회의 해산을 요구합니다 가까운 돈을 국회의 뿐입니다 국회의 해산을 요구합니다
# 실제 요약문 : 국회해산
# 예측 요약문 :  자유한국당
#
#
# 원문 :  미친 가만히 한국의 한국에 정의가 희망이 있다면 반드시 구속시키고 전재산 하고 강력처벌 해라
# 실제 요약문 : 양진호 구속 강력처벌
# 예측 요약문 :  국회의원
#
#
# 원문 :  다시는 이런일이 진실을 밝혀주세요
# 실제 요약문 : 투신 진실을 밝혀주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  엄중한 수사 부탁드립니다
# 실제 요약문 : 배우 그리고 김기덕
# 예측 요약문 :  국회의원
#
#
# 원문 :  한다는 국민의 청원이 많은 같아요 특검 하나로 똑같은 하나로 제목 대한 문무일 검찰 대한 특검을 청원합니다 뜻을 힘을 모아 또한 아래 링크로 모여 주세요
# 실제 요약문 : 사퇴 청원 특검 하나로
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나 전국으로 바이러스가 그로인해 학교는 개학이 바이러스에 가능성이 단체로 단체로 많은데 만약에 다같이 각자 지역 지역 위험이 빨리
# 실제 요약문 : 코로나 초 중 고 휴가
# 예측 요약문 :  국회의원
#
#
# 원문 :  갑질만 해대는 대한항공은 나라를 대표하는 대한 을 쓰게 해서는 안됩니다 나라
# 실제 요약문 : 대한항공의 대한을 못쓰게 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  장이 죽은 청원에 동참해주세요
# 실제 요약문 : 죽은
# 예측 요약문 :  자유한국당
#
#
# 원문 :  중의
# 실제 요약문 : 양진호를 엄벌하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  고통을 받아야 한다면 있겠습니까 모든걸 있습니다 하는것 아닌지 ㅠㅠ 오늘아침 아직 자고 있네요 철저한 수사와 청원 합니다
# 실제 요약문 : 대진침대 철저한 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  마약 진짜 쓰레기 같은 기획사 입니다 돈 그동안 이번엔 제대로 승리 군입대 막아주세요 제대로 정말
# 실제 요약문 : 수사해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  입니다 1 가족 소중한 재산을 가까이 벌써 2년 가까이 있습니다 국가적인 처벌로 또다시 이런 사기 행위가 처벌 해주시길 이에 청원하는
# 실제 요약문 : 처벌을 위한 청원
# 예측 요약문 :  국회의원
#
#
# 원문 :  https www1 president go kr petitions page
# 실제 요약문 : 폐지를 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  끝나고 많은 있습니다 그런데 개학을 하고 발생시 확산 있고 최악의 동안 감염 여부를 어려워 가족 있습니다 면역력이 약한 사람들 또한 있을 때문에 충분히 빨리 조치를 취해주세요
# 실제 요약문 : 우한 내려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  태풍이 한반도 전국
# 실제 요약문 : 태풍 인한
# 예측 요약문 :  국회의원
#
#
# 원문 :  처음으로 올립니다 이 사건은 도저히 언론 이건 저도 하지만 대통령도 경찰도 하나 하지만 대한민국 보여주세요 대통령이 대한민국을 돌려주세요 기사보고 사건 이후
# 실제 요약문 : 사건 진실을 알고 싶습니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  정형식 파면하라 1 2 대한민국에서 되는 것이 없다고 우리 3 물건을 투명한 사건을 4 문재인 다른 달리 것을
# 실제 요약문 : 정형식 판사 파면하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  어떻게 해제 동의를 했는지 제대로 바랍니다 자세한 내용은 기사를
# 실제 요약문 : 어떻게 해제 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  사실상 정도의 많은 노력을 요구하는 그런 일자리를 아무 없이 있었던 아무런 위해 있는 사람들을 무시하는 행위입니다 다시 한번 바랍니다
# 실제 요약문 : 인천공항
# 예측 요약문 :  국회의원
#
#
# 원문 :  지하철 위치한 발전과 경제 크게 것이며 또한 수도권 주변 역할을 것입니다 지하철 촉구하며
# 실제 요약문 : 촉구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  속이 다른 이런 정치인이 국민의 국민의 혈세로 막대한 급여를 받고 있습니다 합니다
# 실제 요약문 : 사퇴하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  무전유죄 유전무죄
# 실제 요약문 : 정형식 파면요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  최근 프로그램을 보니 없을 수도 있는 일본 판결을 받았다고 합니다 재판 일본 의해 판결이 미리 증거가 같습니다 일본이 문제로 우리나라에 부당한 하는 상황에서 의사의 당시 일본의 일본 있을 같습니다
# 실제 요약문 : 의사 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  박수진 배용준 병원 특혜 조사해주세요
# 실제 요약문 : 박수진 배용준 병원 특혜 조사해주세요
# 예측 요약문 :  자유한국당
#
#
# 원문 :  the korean do the korea
# 실제 요약문 : 시험
# 예측 요약문 :  국회의원
#
#
# 원문 :  경기도지사 해야하는 이유가 이재명 본인들
# 실제 요약문 : 이재명 경기도지사 하세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  국회의원 세비를 최저시급으로 나라와 국민을 위한 국회의원 국회의원들을 이상 없으며 이는 대한민국의 발전을 가장 그래서 국회의원 세비를 최저시급 바랍니다
# 실제 요약문 : 국회의원 세비를 최저시급으로 지급해 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  조선일보는 대표적인 기득권 보수 함께 국민들을 속이고 현정부의 온갖 지방선거 최고 이슈가 되는 김경수 아직 조선일보 sbs 철저히 조사 해야만 건강한 사회가 생각해서 청원합니다 필요합니다 우리가 지켜야 합니다
# 실제 요약문 : 조선일보 폐간 모읍시다
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재 불공정한 불공정한 반드시 합니다 그리고 공정한 합니다
# 실제 요약문 : 정시확대 학종 폐지하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  피해자가 합니다 가까운 행동에 무기징역이 맞다고 생각합니다 이런 사회 집단으로 무자비하게 방치한 경찰도 철저히 조사해서 징계 해주세요
# 실제 요약문 : 광주 폭행 엄벌을 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  국가 하고 국민 알권리 자유한국당의 행태를 보니 국민의 공개 아닌가 싶어서 청원합니다 국민 알권리 차원에서 공개해 주십시오 진실을 국민의 알권리 차원에서
# 실제 요약문 : 대통령
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  사건이 당시 국회 청문회 위증을
# 실제 요약문 : 조여옥 대위 처벌을 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  공무원의 국민의 위해 일하는 지금 국민연금 하면서 자기들 평생 없습니다 국민연금 공무원 월급 것을 국민투표 제안합니다
# 실제 요약문 : 국민연금 공무원 월급 중단
# 예측 요약문 :  국회의원
#
#
# 원문 :  사람이 먼저다 대한항공 명예를 크게 망신 시키는 아직도 않은 남아있는 있는 재벌 2 3 대한 바랍니다 국민들은 다른 하루라도 대한항공 미투
# 실제 요약문 : 조현민 적폐 대한항공 갑질
# 예측 요약문 :  국회의원
#
#
# 원문 :  자기 정치적으로 자유한국당 해산 전원 의원직 박탈을 청원합니다 이번 사건 정확히 정부를 정치적으로 이용하고 우롱하고 국민에게 자유한국당 해산 전원 의원직 박탈을 청원합니다
# 실제 요약문 : 자유한국당 해산 전원 의원직 박탈 청원
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  부산 어느 교사가 폭행 서슴치 않게 하고 하였습니다 피해자는 계속 늘어나고 있고 교사를 않으면 피해자는 것입니다 사실 확인 조치 부탁드립니다
# 실제 요약문 : 성희롱 폭행 하는 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재 코로나19로 인해 피해를 보고 있는 국민에게 어디에 없는 원합니다
# 실제 요약문 : 코로나19 공개 원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  교사가 학교가 초등 2학년 2018년 지금까지 학대하고 있습니다 통해 모든 사실 아직 못한 부분은 있습니다 어머니의 이름은 입니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 문재인 대통령님 학대를 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  자유한국당은 대한민국 대한민국 절대 나라에 도움이 않아 대한민국 국민의 사람으로써 사랑하는 마음으로 청원이 자유한국당 다시 이들이 만들지 못하고 가입 못하게 주십시요
# 실제 요약문 : 자유한국당 청원합니다
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  저는 갑질에 억울하고 철저한 조사를 원합니다 저는 키우는 제가 위하여 책임을 나몰라라 하고 있습니다 또한 필요한 인하여 났습니다 갑질을 철저히 조사하여 주시기를 바랍니다 있는 일이 없습니다
# 실제 요약문 : 갑질
# 예측 요약문 :  국회의원
#
#
# 원문 :  힘없고 사람들은 언제까지 살아야 합니까 jtbc 보고 치밀어 누구든 해주세요 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 위디스크 양 회장 철저히 조사해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :
# 실제 요약문 : 나경원 박탈해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  무노동 청원합니다 시대가 법도 바뀌어야 합니다
# 실제 요약문 : 국회의원 무노동 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  또 청소년들의 이제 싫습니다 성추행 가해자들은 포기한 감히 하는 아이들 형벌이 알고 문대통령님 아이를 키우는 이나라에 국민으로써 간절히 원합니다 저런 다시는 무거운 해주세요
# 실제 요약문 : 청소년법 폐지해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  얼마전 의료보험 없애주세요 사실 한번에 어렵습니다 여러가지 이유로 두고 다시 너무 차이가 많이 납니다 부담이 없고 또한 폐지해주세요 아이를 갖고 싶어도 병원비 부담이 너무 큽니다 부탁드립니다 고통받는 도와주세요
# 실제 요약문 : 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  여태까지 안하면서 보면서 이제 도무지 참을 없습니다 정말 이건
# 실제 요약문 : 홍준표 대한민국
# 예측 요약문 :  국회의원
#
#
# 원문 :  20만
# 실제 요약문 : 광주 폭행 링크
# 예측 요약문 :  국회의원
#
#
# 원문 :  입법을 결국 무시한 자유한국당의 국민의 아니고 확실히 드러났습니다 자유한국당을
# 실제 요약문 : 유치원
# 예측 요약문 :  국회의원
#
#
# 원문 :  우리 대한민국을 그러나 본인들의 바라고 무분별하게 자유한국당이 대한민국을 대표하는 한국당 대신 것이 맞습니다 이에 청원을 올립니다
# 실제 요약문 : 언론에서 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  조재현 김기덕 그들의 추악한 거부한 이들을 거짓이 진실이 정확한 수사를 부탁드립니다 pd 아직 하지 않는 일이 이해가 되지 권력이 세상이 아니라 깨끗한 마음으로 본인이 사랑하는 일을 할수 있는 세상이 철저한 수사를 꼭 부탁드립니다
# 실제 요약문 : 조재현 김기덕
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  현재 최근에 가서 지원금을 있습니다 때문에 재난지원금 현재 받을 있게 해주세요
# 실제 요약문 : 코로나 확대해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나19를 위해 사용 공개해주세요 마스크 지원 코로나 있는지 비롯한 조사하여 투명하게 공개해주세요 수많은 불구하고 마스크 것이 도저히 않네요
# 실제 요약문 : 코로나19 사용 공개해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  원래 의해 일본이 말하는 엄연히 마음대로 잘못된 잘못 알게 입니다 해결해 주시길
# 실제 요약문 : 독도 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  갑질만 일삼는 대기업 더이상 국민은 없습니다 대한항공의 경영에서 합니다
# 실제 요약문 : 조현민 조현아 회사 경영에서
# 예측 요약문 :  국회의원
#
#
# 원문 :  평창올림픽 위해 평창올림픽 오히려 반대하는
# 실제 요약문 : 자유한국당 나경원의원 의원직 사퇴
# 예측 요약문 :  국회의원
#
#
# 원문 :  있지만 반대를 하는 사람은 모든 국민 세금 모두다 공개하라
# 실제 요약문 : 김기식 절대 안됩니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  근처 세워주세요 교육 파렴치한 행동을 알아야 아닙니까 범죄 원합니다 반드시 세워주세요
# 실제 요약문 : 세워주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 시점에 아이들 부탁드립니다 맞벌이 아이들 건강이
# 실제 요약문 : 부탁드려요
# 예측 요약문 :  국회의원
#
#
# 원문 :  저는 초등학교 2학년 자녀의 솔직히 초등학교 없다는 것이 너무 가슴이 아프네요 애들 돈도 많이 없네요 방과후 그나마 아무것도 없다는 것이 참으로 제발 하는 바램입니다 혜택이 없는데
# 실제 요약문 : 늘려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  울산 성민이 사건 진실이 좋겟습니다 너무도 너무너무 죽음을 하지만 해당 어린이집 필리핀에서 너무도 잇습니다
# 실제 요약문 : 울산 성민이사건
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재 학생입니다 현재 갑자기 소식을 들어 이렇게 청원을 올립니다 한다는건 알지만 이렇게 더욱 부디 말아주세요
# 실제 요약문 : 폐지를 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  구속해주세요
# 실제 요약문 : 조여옥대위를 구속해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  제도 취지는 좋습니다 하지만 많습니다 그리고 필요한 돈을 거의 죽이는 제도 폐지해주세요
# 실제 요약문 : 제도 폐지해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  유전무죄 무전유죄 문재인 대통령님 사법부의 적폐를 국민의 판결이 됩니까 나라가 어떻게 인간이 국민을 국민의 삼성이 나라 나라
# 실제 요약문 : 정형식 판사 사퇴
# 예측 요약문 :  국회의원
#
#
# 원문 :  제발 정부는 전기세 전기세 많이 없는 서민들 위해 한시적 7월 8월 전기세 부탁 드립니다
# 실제 요약문 : 위해 7 한시적 전기세
# 예측 요약문 :  국회의원
#
#
# 원문 :  강서구 아파트 살인사건의 가해자 법정 처해주세요 폭행하고 협박하고 죽음에 가해자를 처벌해주세요 그래야 살고 그동안 저런 같아요
# 실제 요약문 : 강서구 아파트 살인사건
# 예측 요약문 :  자유한국당
#
#
# 원문 :  2 집이 1 문재인 대통령님 어떻게 해야 될까요
# 실제 요약문 : 어떻게
# 예측 요약문 :  국회의원
#
#
# 원문 :  사는데 뉴스를 보고 깜짝 대놓고 폭행을 저지르고 경찰도 않는 안전한 대한민국을 위해서 공권력 강화 조폭 반드시 필요합니다
# 실제 요약문 : 광주 폭행사건 강화 해야합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  항상 공무원이 정보를 먼저 것이 생각하십니까 발표 등을 조사하여 모든 바랍니다
# 실제 요약문 : 공무원 특검
# 예측 요약문 :  국회의원
#
#
# 원문 :  일본의 나라가 혈세로 일본 것은 국민 위배되는 생각됩니다 일본 무리하게 추진하고 사용한 담당자 해임 특별한 조치를 요청합니다
# 실제 요약문 : 징계 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  우리나라에서 국제적 이게 무슨 서로 어떤 문제가 있었는지 없지만 국민과 입니다 철저히 조사해서 앞으로는 이런 몰상식한 선수들은 상관없이 영구 바랍니다
# 실제 요약문 : 진상조사 징계 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  kbs 수신료 하라 한심한 kbs
# 실제 요약문 : kbs 수신료 반납 페지 하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  조여옥 대위의 위증을 엄벌해
# 실제 요약문 : 조여옥대위 위증
# 예측 요약문 :  국회의원
#
#
# 원문 :
# 실제 요약문 : 김성태 국회의원
# 예측 요약문 :  국회의원
#
#
# 원문 :  결정 놓고 맞춰서 작성한 정형식 판사에 대한 수사를 주세요 지극히 않은 판결을 보니 보다도 냄새가 납니다 분명 관리 하는 의심이 갑니다 이와 같은 하는 없게
# 실제 요약문 : 정형식 대한 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  해서 국민을 농락하고 사실과 양심도 없이 방송을 국민을 사장 관련된 모든 사람을 사퇴 시켜 부탁드립니다
# 실제 요약문 : 국민을 사퇴 시켜주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공 이명희 당장 폭언 동영상이 이미
# 실제 요약문 : 대한항공 이명희 당장 구속하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  제주도 난민 너무 대한민국 난민 수있게 해주세요 따라 난민을 보호할 의무가 있는 나라 불구하고 난민 인정 안되는 나라 국민들이 하네요 그럼 그럼 전국에 난민을 있게 해주세요
# 실제 요약문 : 제주도 있게 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  조양호 조현아 조현민 조현아 얼마 그들이 있는 다시 것이다 조양호 일가 자체가 갑질의 해서 문제가 아니라 철저하게 드러난 대해서 조사를 해야 한다 그리고 통한 경제 한다
# 실제 요약문 : 대한항공을
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  범죄에 준하는 무분별한 쉽게 아동 그리고 각종 기사에 기사를 바로 나오는 각종 만화 각종 아이들을 국민의 중요한 지켜주시고 우리의
# 실제 요약문 : 어린이
# 예측 요약문 :  대한항공
#
#
# 원문 :  등등 이루 말할 없는 되었습니다
# 실제 요약문 : 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 작금의 대통령님 제발 얼마나 않습니다 어떻게 해야합니까 아니라 정부가 이번 정부에서 긴급 간곡히 답변과 감사하겠습니다
# 실제 요약문 : 소상공인 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  장애인 폭행 사건 기사를 보고 정말 사람이 눈과 귀를 합니다 이에 동시에 제안합니다 1 조사 철저 대책 기관 등이 비롯한 전체 전수조사 2 특별 관리 철저
# 실제 요약문 : 조사 강화
# 예측 요약문 :  국회의원
#
#
# 원문 :  단역배우 자매 자살 사건 재조사 처벌해주세요 12명 그들은 인간이 아닙니다 성기를 했던 경찰도 처벌해주세요 가해자 12명 똑같은 고통 받게해주세요 인간이 아닙니다 강아지 요즘 얼마나 모두 처벌을 해주세요
# 실제 요약문 : 단역배우자매 자살 사건
# 예측 요약문 :  자유한국당
#
#
# 원문 :  청와대 청와대 맞는 대부분의 국민 청원은 철저히 있는 이런 국민을 우롱하는 밖에 않고 도움이 해주시기 바랍니다
# 실제 요약문 : 청와대 국민 폐지를 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 봅니다 근간을 해치는 행위입니다 정당하게 주식을 주고 행위는 하나 하지 클릭 주지 않고 공매도를 하는 행위는 심각한 후에 신뢰를 수있는 행위입니다 필요합니다
# 실제 요약문 : 등
# 예측 요약문 :  국회의원
#
#
# 원문 :  오늘 양승태 버젓이 거짓말로 국민을 기만하고 있습니다 최고 어떤 공정하고 정의로운 판결을 안하고 또는 위해 한다면 아니라 판결에 신뢰가 하루빨리 특검을 실시하여 이나라의 정의를
# 실제 요약문 : 양승태 대해 특검을
# 예측 요약문 :  국회의원
#
#
# 원문 :  조국 장관 교육 정치인의 국민들의 분노를 사는 가운데 경기도 그의 sns에 못할 자격이 없다고 생각합니다 그의 사퇴를 청원합니다
# 실제 요약문 : 경기도 사퇴를 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  불구하고 실제 요청합니다 때문에 않을 알고있습니다 하지만 해당 오늘도 수익을 있습니다 심지어 금전적 이득을 있는 상황입니다 국민여러분의 목소리를
# 실제 요약문 : 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  개학 마스크를 학교에서 일괄 지급하고 시스템 신분 되고 아주 있으니 쉽게 같습니다 마스크를 없는 학생을 위해 마스크 못한 학생도 발생하지 않을 것입니다
# 실제 요약문 : 개학 마스크
# 예측 요약문 :  국회의원
#
#
# 원문 :  국회의원 4년간 민주당이 북한으로 가면 한해 예산이 북한에 보내지 말고 같이 좋겠습니다
# 실제 요약문 : 말고 같이
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민을 이에 합당한 처벌이 있어야 합니다
# 실제 요약문 : 조여옥대위 위증죄 처벌해 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  보고 잘못된 판단을 했다고 안됩니다 최선을 잘못이 누가 앞으로 보고 하고 한다면 누가 충분합니다 처벌을 반대합니다
# 실제 요약문 : 소방관 처벌을 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 당장 내는 연금도 의문입니다 모르고 돈을 책임 대통령 진짜
# 실제 요약문 : 국민연금 돌려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  김기식 국회의원 시절 해외출장 의견이 특히 야당의 생각합니다 일부 언론도 이에 대해 꾸준히 기사를 국민 판단이 있읍니다 이참에 20대 국회의원의 해외출장 모두 국민의 사람으로서 정확히
# 실제 요약문 : 국회의원 해외출장 해주십시요 20대
# 예측 요약문 :  국회의원
#
#
# 원문 :  비싼 세금으로 세금이 모르는 소위 말하는 주범 국제 못한 행동을 하고 보면 바랍니다
# 실제 요약문 : 박지우 국대 박탈
# 예측 요약문 :  국회의원
#
#
# 원문 :  동의를 얻은 제주도 난민 반대 청원글이 원인 없이 되었습니다 한번 청원은 하는데 해명을 요구합니다
# 실제 요약문 : 제주도 관한 대한
# 예측 요약문 :  국회의원
#
#
# 원문 :  요즘 뉴스를 보면 민주당 많이 느낍니다 드루킹 수사 있어도 청와대는 아닌 자유 합니다
# 실제 요약문 : 김경수 강력한 수사를 바랍니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  장충체육관 취소한 잘못된 것입니다 처리 할수 있도록 해주세요
# 실제 요약문 : 장충체육관 사용허가 불법취소 해주세요
# 예측 요약문 :  자유한국당
#
#
# 원문 :  최근 같은 사건으로 성추행 성폭력 같은 불합리한 일을 불구하고 사실을 대한 고소 등을 두려워 이에 대하여 제대로 이야기를 하지 못하고 있는 경우가 많습니다 이에 대해 대한 폐지를 요청합니다
# 실제 요약문 : 대한 폐지에 대한 청원
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  어제 2006년 매크로 사용한 일과 관련하여 요청합니다 그래야 형평성에 맞지 않겠습니까 그동안 없어서 일방적으로 평등하게 특검수사를 강력하게 요청합니다
# 실제 요약문 : 자유한국당 매크로 합시다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  모두가 북한이 저지른 하지만 북한이 했다는 증거는 합니다 그래서 정확한 사실을 없습니다 이를 정확히 필요하다고 생각합니다 사건을 국민들이 정확히 있게 도와주세요 대통령님의 현명한 선택을 기다리겠습니다
# 실제 요약문 : 천안함 필요합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  전국 가장 아름다운 도로 기사 아니고 차량이 아닙니다 아름다운 길을 않고 공사 무분별한 환경 공사를 막아 주시길 청원합니다
# 실제 요약문 : 무분별한 제주도 비자림로 주십시오
# 예측 요약문 :  국회의원
#
#
# 원문 :  한국으로 국제 사람들에게 말을 합니다 베트남 쉽게 한다 이런 상처를 받습니다 사람들에게 직접 https youtu be 유튜브 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 유튜브 tv
# 예측 요약문 :  국회의원
#
#
# 원문 :  김학의 임은정 김학의 사건을 한을 모두 해주세요
# 실제 요약문 : 김학의
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공 자격이 없는 사람입니다 모르는 대한민국을 대표하는 못쓰게
# 실제 요약문 : 대한항공 내려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  도저히 이해할수가 없습니다 하시는 분들이 아니고 굳이 서민들이 살고 있는 왜 부탁드립니다 그리고 특히 없어요 근데 그게 말입니까 뭐가 다른가요 자세히
# 실제 요약문 : 인천
# 예측 요약문 :  국회의원
#
#
# 원문 :  마스크 현재 국민들이 매우 혼란을 겪고 있습니다 세금 처럼 받아 있을 생각이 듭니다 마스크를 세금 주소로 좋겠습니다
# 실제 요약문 : 마스크를 보내주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  양승태 대법원장 시절 관한 의혹은 매우 위중한 것입니다 하지만 5년 이하의 처벌 밖에 재판 처벌법을 감히 이에 청와대에서 대한 특별법을 만들고 처벌을
# 실제 요약문 : 관한 처벌 특별법을 청원합니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  조선일보는 아직도 이나라에 있습니다 후손들에게 이런 더이상 안됩니다
# 실제 요약문 : 조선일보를 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  문재인 김정은 서로 받는 자리에서 누구나 있도록 욕을 했습니다 이것은 동영상을 듣는 모든 사람이 들을 있는 자리에 있는 사람들도 들을 밖에 없는 이는 명백히 대한 어렵게 남북 위협하는 공개 사과와 징계를 요구합니다 나옵니다
# 실제 요약문 : 징계를 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  제2의 삼성증권 사태 반드시 공매도 폐지해야 합니다
# 실제 요약문 : 삼성증권 사태 공매도 반드시 폐지
# 예측 요약문 :  국회의원
#
#
# 원문 :  동일한 국회의원 전수 조사를 청원합니다
# 실제 요약문 : 국회의원 전원 위법사실 전수조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국이 국제마피아 조폭 이재명 은수미 즉각 사퇴 촉구합니다 아래 청원에 힘을 모아주세요 https www1 president go kr petitions
# 실제 요약문 : 조폭과 이재명 은수미 즉각 사퇴 촉구
# 예측 요약문 :  국회의원
#
#
# 원문 :  정형식을
# 실제 요약문 : 정형식판사 파면해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 검찰이 하는 즉각 멈춰주세요 물론 청와대 대통령이 가 수사에 영향을 이번 수사는 영향을 줘야 한다고 생각합니다 맞지 않는 말을 했다고 잡아서 수사를 하는 것은 민주주의가 추구하는 맞지 않다고 생각됩니다
# 실제 요약문 : 조국 수사를 즉각 멈춰주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나19로 상황에 대한민국 국민으로서 함께 있도록 정부 차원의 아니라 도움을 수도 없고 때문에 작은 어려운 상황에 안에 마스크가 코로나19가 수는 없습니다 작은 있도록 대한민국 기회를 주시길 바랍니다
# 실제 요약문 : 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  우리나라에서 거주하고 있는 알고있습니다 우리 지키고 세금 내고 대한민국 국민으로써 의무 지키고 있습니다 우리 있는 우리 말이 안됩니다 될수 우리나라 즉각
# 실제 요약문 : 대한민국에서 외국인 투표권 폐지 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  국가를 위해 권력에
# 실제 요약문 : 김종필 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  아이 다같이 보육교사의 누가 아이를 보육교사의 누가봐도 아닌가요 어떻게 아이 다같이 일자리 아니라
# 실제 요약문 : 부산
# 예측 요약문 :  국회의원
#
#
# 원문 :  지극히 대한이라는 이름이 들어간 상호를 사용하는 것은 형평성에 일이라 대한민국의 이미지 있으며 국가의 막대한 일어난 오로지 개인의 의한 일삼고 있는 대한이라는 태극마크를 안된다는
# 실제 요약문 : 대한항공의 대한을 빼주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  1 방용훈과 자식들의 대해 수사하여 2 당시 검 유착 또는 대하여 깊이 수사 엄벌하여 다시는 않도록 해주시기 바랍니다
# 실제 요약문 : 이미란씨 관련 방용훈과
# 예측 요약문 :  자유한국당
#
#
# 원문 :  일련의 모두 연예계 언론사 정치인 대기업 검찰 유착 비리 불법 성폭행 성매매 살인 등의 확실한 조사를 바랍니다
# 실제 요약문 : 버닝썬 장자연 조선일보 방용훈 이미란 모두
# 예측 요약문 :  자유한국당
#
#
# 원문 :  이번엔 김기식 금감원장 나왔는데 그럼 국회의원 전원다 전수조사해서 있으면 반드시 처벌해야 합니다 없읍니다
# 실제 요약문 : 국회의원들 외유성 전수
# 예측 요약문 :  자유한국당
#
#
# 원문 :  으로 사회적 일으킨 사이트 폐쇄를 요청드립니다 미투운동이 이런 짓을 일삼고 방치한 맞다고 봅니다 심각합니다
# 실제 요약문 : 사이트
# 예측 요약문 :  국회의원
#
#
# 원문 :  어떻게 정말 못하고 있는게 있는 이게 생명이 그게 당연히 현실 조사해 주세요
# 실제 요약문 : 삼성병원 특혜 비리 조사해 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  요즘 일으키는 생명을 살아가는데 정작 나라에서는 국민의 관심이 중국에서 중국발 가면 갈수록 있는데 정작 쓰레기 하는데 아무 중국에 못하고 이렇게 죽어가고 우리나라 정부가 대책을 세워주세요
# 실제 요약문 : 미세먼지
# 예측 요약문 :  국회의원
#
#
# 원문 :  공인중개사 명백한 대다수의 의견을 그대로 근거가 무엇인지 국가에서 철저하게 않고 수많은 요구합니다
# 실제 요약문 : 문제
# 예측 요약문 :  국회의원
#
#
# 원문 :  있는 어린이집에 cctv 모든 교육을 받는 cctv 안심하고 믿고 있게 해주십시오
# 실제 요약문 : cctv 청원합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  실시간 국가에서 것은 개인의 집안의 재산이 있으며 스스로 들어간 사람입니다 그런 개인의 문제로 국가의 혈세를 한부모가정 위한 곳에
# 실제 요약문 : 그랜드캐년 사고
# 예측 요약문 :  국회의원
#
#
# 원문 :  분식회계 아주 잘못된 정부는 했는지 심히 의심이 삼성의 이제 맘놓고 불법을 된다는 기회는 공정 이렇게 과연 나라입니까 기업은 안되고 있는 기업은 된다는 겁니까 개탄스럽습니다
# 실제 요약문 : 삼성바이오로직스
# 예측 요약문 :  국회의원
#
#
# 원문 :  도데체 내가 남의 됩니까
# 실제 요약문 : 없애주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  똑같은 교육을 받으며 함께 고작 못하고 동떨어진 생활을 아니라 모든 청소년들의 도저히 납득이 없습니다 함께 아닌 발이 청원글을 부디 마음을 소중한 부탁드리겠습니다
# 실제 요약문 : 규제를
# 예측 요약문 :  국회의원
#
#
# 원문 :  서민들 세금으로 안되는 정말 어이없습니다 민주당은 당장 이재명 은수미를 철저히 편하게 살수있는 사회를
# 실제 요약문 : 이재명 은수미 철저히
# 예측 요약문 :  국회의원
#
#
# 원문 :  막막합니다 이렇게 하시면 없는 이들은 아이들에게 앞섭니다 제발 저희 미래를 부탁드립니다
# 실제 요약문 : 건설
# 예측 요약문 :  국회의원
#
#
# 원문 :  이재용 다시 해야 합니다 하루종일 빠졌습니다 세상 사법부의 깨끗한 바랍니다
# 실제 요약문 : 정형식 퇴출 사법부
# 예측 요약문 :  국회의원
#
#
# 원문 :  무노동 무임금 으로
# 실제 요약문 : 국회의원 세비
# 예측 요약문 :  국회의원
#
#
# 원문 :  pc방 전국 학생들이 밀폐된 강제 시켜주세요
# 실제 요약문 : 학원 운영
# 예측 요약문 :  국회의원
#
#
# 원문 :  포스코 얼마전 이번 민주노총 포스코 해임을 당하는 일이 발생 했습니다 빠른 부탁드립니다
# 실제 요약문 : 포스코 해임
# 예측 요약문 :  대한항공
#
#
# 원문 :  남북 단일팀 반대 평창올림픽을 또한 대한민국 국민들의 단일팀 반대 70 거짓 근거로
# 실제 요약문 : 평창 나경원 자격박탈 제안
# 예측 요약문 :  국회의원
#
#
# 원문 :  최저임금으로 최저임금 하고 싶네요 국회의원들 세금으로 쓰고 최저임금으로 임금 일하는 최저 임금 최저임금 얼마나 알지 못한 해주세요 국회의원 영수증 받았으면 좋겠네요
# 실제 요약문 : 국회의원 최저시급으로
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 양승태 의혹 관련 특검을 해야한다고 봅니다 지금까지 부당한 판결 대한 그런데 의혹이 심지어 청와대 세월호 있다고 합니다 이번 양승태 사법부는 반드시 특검을 해야한다고 봅니다
# 실제 요약문 : 양승태 특검을 요구합니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  없어서 조선일보 대한민국 어떻게 경찰도 검찰도 하는 보다는 하는 여기는 인간들 어떻게 안되나요 폐간 시켜주세요
# 실제 요약문 : 조선일보 재조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  이대로 피해자는 있는데 말도안됩니다 지금당장 국회는 장자연사건 도대체
# 실제 요약문 : 장자연사건
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한 청원을 합니다 음주운전 사고 안된다 구속 수사를 해야 한다 몰라도 계속 2차 3차 구속 음주운전 바란다
# 실제 요약문 : 음주운전
# 예측 요약문 :  국회의원
#
#
# 원문 :  대통령님께서 곳에서 대통령님 잠시
# 실제 요약문 : 문재인대통령님
# 예측 요약문 :  국회의원
#
#
# 원문 :  자매 대해 kbs mbc sbs jtbc tv조선 연합뉴스 있는가 국민이 묻고 있는데 기자 모든 서로 방송 말고 진실 방송 부탁 한다 없애야 진정 부디 살아있는 있다면 두자매 진실 그의 가족 한을 바란다 같이 동의 보다 고인의 으로 봅니다
# 실제 요약문 : 대해 kbs mbc sbs jtbc mbn tv조선 연합뉴스
# 예측 요약문 :  매크로 매크로
#
#
# 원문 :  3월 24일 경기 상황에서 잠시 선수와 잠시 제대로 않고 받은 것이 아닌가 청원합니다 제대로 판정을 원합니다
# 실제 요약문 : 심판 조사
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  법안을 청원이 글이
# 실제 요약문 : 조사해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  이런저런 마시고 하세요 국민이 합니다 지지합니다
# 실제 요약문 : 하세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  부적절한 청원합니다
# 실제 요약문 : 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대통령 문재인 국민의 정치를 하는것이 아니라 문재인 국민의 명령이다 당장
# 실제 요약문 : 문재인 탄핵
# 예측 요약문 :  국회의원
#
#
# 원문 :  천안함 재조사 청원 글이 너무 분산되어 글이 올라오고 있습니다 아무리 글이 20만명 이상 동의한 글이 없으면 불가능합니다 현재 동의 수가 가장 많은 아래 링크에 동의 부탁드립니다 https www1 president go kr petitions
# 실제 요약문 : 천안함 재조사 청원 제발 링크 으로 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  조여옥 대위 관련 수가 많은 곳에서 동의 해주시면 좋을것 같습니다
# 실제 요약문 : 조여옥 대위 청원 관련
# 예측 요약문 :  국회의원
#
#
# 원문 :  더위에 전기세 누진세 때문에 전기세 누진세를 폐지해
# 실제 요약문 : 7 전기세 누진세 폐지해 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  모르지만 광주 합니다 어떤 어떻게 그렇게 할수 있었는지 모두 자세히 조사해주세요 피해자는 그렇게 의지를 가진 사회 분위기를 만들 있다고 생각합니다 조사해주세요
# 실제 요약문 : 광주 처벌
# 예측 요약문 :  국회의원
#
#
# 원문 :  권리를 성인이 그것도 임금이 내는 알았습니다 교육이 건전한 이루어지고 사회가 조금 학교에서
# 실제 요약문 : 초중고
# 예측 요약문 :  국회의원
#
#
# 원문 :  경북 예천군 해외연수 폭행 거짓 떨어뜨린 엄중한 처벌 부탁드립니다
# 실제 요약문 : 경북 예천군 군의원 폭행사건
# 예측 요약문 :  국회의원
#
#
# 원문 :  하는데 만일 추진하고 자기를 못하고 되는 이런 반대합니다 개는 없다 안된다
# 실제 요약문 : 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  세월호 대한 국민의 이런 것을 조사하여 다시는 이런일이 발생하지 않도록 하려고 하는 청문회 에서 뻔뻔한 거짓말을 조사하여 다스려야 합니다
# 실제 요약문 : 위증 조여옥 대위 처벌해 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  하고 있습니다 그러면 사는 사람들은 그들이 조작을 하고 있는지 제대로 하고 있는지 없습니다 심지어 최근에 하다가 2번 나온 있습니다 그리고 현실적으로 나오는 것이 말이 된다고 생각하십니까 제발 부탁입니다 공정하게 해주세요
# 실제 요약문 : 무조건
# 예측 요약문 :  국회의원
#
#
# 원문 :  사립유치원 사립유치원 불법
# 실제 요약문 : 사립유치원
# 예측 요약문 :  국회의원
#
#
# 원문 :  제목 그대로입니다 일반 하고있는 공무원들 누가 선량한 한번 당신들이 아닙니까 나라의 당신들이 없다면 공무원 국토부
# 실제 요약문 : 비롯한
# 예측 요약문 :  국회의원
#
#
# 원문 :  정부는 무엇을 하고 있습니까 국민의 안전과 치명적인 있는 사회적 지고 하는 국민들을 위해서라도 하루빨리 필요합니다
# 실제 요약문 : 관한 필요합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  학생들은 학교에 되었으면 무엇입니까 아무런 없이 발표하고 무조건 그렇게 학원 학교 모두다 아닌가요 그냥 국민이 아닙니다 정부의 대책을
# 실제 요약문 : 우한폐렴
# 예측 요약문 :  국회의원
#
#
# 원문 :  동시에 아이들은 마스크를 없습니다 지금 터무니없는 가격으로 무려 에서 있습니다 게다가 벌어지고 있습니다 안전한 국산 판매 해주시면 아이들을 유치원에 같습니다
# 실제 요약문 : 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  일본 후쿠시마 학교 뉴스를 봤습니다 훨씬 다니는 사람이 사는 쓰는 사용 해주세요 이미 아파트 명단 공개 부탁드립니다 우리나라도 제일 받고 사람이 대해서 합니다
# 실제 요약문 : 해주세요
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  아직 사건을 되었는지 궁금합니다 피해자를 위해서라도 파렴치한 학생들의 처벌을 간절히 원합니다 저게 입니까 우리나라는 법이 입니까
# 실제 요약문 : sbs 그것이 알고
# 예측 요약문 :  국회의원
#
#
# 원문 :  음주운전 는 야구 sns 선수는 전혀 맞습니다 모두 선수 맞다고 봅니다 봅니다 삼성 선수 해제 간절히 바랍니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 해제 부탁합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  의원을 비롯한 음주 거부한 국회의원을 처벌해서 처벌 해주세요 대한민국의 국회의원이 어떻게 음주운전을 하며 법과 모범이 일을 할수 있겠습니까 자격이 없다고 생각합니다 그리고 같은 국회의원들도 아무런 처벌도 하려 하지않고 있습니다 국민들이 있습니다 이대로 놔두면 하나의 만들어서
# 실제 요약문 : 음주운전 국회의원 처벌바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 대한 문제점 국민이 무엇인지 돌려주세요 여러분
# 실제 요약문 : 국민연금 폐지
# 예측 요약문 :  국회의원
#
#
# 원문 :  도대체 주식시장 겁니까 주가 제발 올해
# 실제 요약문 : 주식시장
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 드러난 여자 빙상연맹 고위직 전명규 청원합니다 아직도 책임자
# 실제 요약문 : 빙산연맹 적폐청산 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나19 백신 빠른 처리 청원합니다 학생들은 일자리 매번 적극적인 현재 국내 국내
# 실제 요약문 : 코로나19 백신
# 예측 요약문 :  국회의원
#
#
# 원문 :  되고 어디있습니까 마스크 있고 있는데 차라리
# 실제 요약문 : pc방 가능하게 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  아직 사건 나오지 않았는데 올려서 여론 근데 먼저 하면서 강력처벌 부탁드립니다 폭행으로 올려서 경찰 수사에 초래하고 경찰을 하고 죄로 강력 처벌 부탁드립니다
# 실제 요약문 : 이수역 여자 강력처벌
# 예측 요약문 :  국회의원
#
#
# 원문 :  이미 뉴스에 있는 새누리당 매크로 특검 요청합니다 대한민국의 모든 적폐를 뿌리 뽑아야합니다 떠나 모든 된다고 생각합니다 이후 청원합니다
# 실제 요약문 : 새누리당 매크로
# 예측 요약문 :  자유한국당
#
#
# 원문 :  반하는 이것은 철저한 있어야 할것입니다 모두 의한 특검을 사건도 철저한 있게 특검을 민주주의를 위해 하면서 자유한국당은 만큼 반드시 특검을 입니다 다시는 대한민국에 않도록 철저한 수사 부탁드립니다
# 실제 요약문 : 한나라당
# 예측 요약문 :  국회의원
#
#
# 원문 :  대상이 되는 법을 때문에 온갖 인해 어렵게 하는 안됩니다 비해 훨씬 이대로 우리나라 만들어 밖에 없습니다 대해 당연히 합니다
# 실제 요약문 : 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번기회에 조사 의혹을 밝혀주세요
# 실제 요약문 : 천안함 진상조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  역할을 주시고 대한민국이 정의로운 사회로 간절히 바랍니다
# 실제 요약문 : 특활비 공개하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  여상규 황우여 처벌해주세요
# 실제 요약문 : 여상규 황우여
# 예측 요약문 :  국회의원
#
#
# 원문 :  일명 없애주세요 아직도 많은 우리 있네요 주변 주민들은 시간이 갈수록 불안합니다 아이들이 청소년 등 많은 우리 조금이라도 나쁜 너무 빨리 만들어 주고 싶네요
# 실제 요약문 : 없애주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공 대한이란 박탈 바랍니다 국가적 문제가 너무 많은 사람들 입니다 인격을 지금의 행동을 일삼고 있는 회사의 모든 박탈 요청합니다
# 실제 요약문 : 대한항공 명칭 변경 원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  경기도 중단하라 성남 김포 신규 경기도에 아파트를 경기도는 지금도 있습니다 경기도 집값 보세요 되어야 합니까 필요합니다
# 실제 요약문 : 경기도 성남 김포 광명
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한 민국 국민이 그것도 자가 단일팀 반대 수많은 만드는 가까운 제발 나경원 의원 평창 올림픽 파면 시켜
# 실제 요약문 : 나경원 의원 평창 올림픽 파면 시켜 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  한국 인천에서 그동안 외국인 이건 아니다 아니다 했는데 명백한 대국민 사기극을 탄핵을 청원한다 뉴스 링크 주소 https m news naver com nhn oid amp aid amp sid1 001 amp n
# 실제 요약문 : 북한 석탄 문재인 정부는
# 예측 요약문 :  자유한국당
#
#
# 원문 :  성민이 사건 증거가 너무도 재수사 해서 억울함을 풀어주세요 얼마나 제발 재수사 해주세요
# 실제 요약문 : 울산 성민이 사건 간곡히 재수사 요청 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  정형식판사 파면하고 이재용 시켜주세요 촛불 아닙니다
# 실제 요약문 : 정형식판사 파면하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공 밀수 아닙니다 처벌해야합니다 안됩니다
# 실제 요약문 : 대한항공 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  안전하고 행복하게 살게 해주세요 아동 인한 범죄를 다른 범죄를 있습니다 가슴이 아이를 생각하면
# 실제 요약문 : 아동 성폭행
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민과 가족들의 건강을 충분히 벌금을 생각합니다 반성하고 벌금을 국민의 피같은 세금으로 지원하는 정책을 빨리
# 실제 요약문 : 세금으로 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  폐지 아닙니까
# 실제 요약문 : 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  아름다운 인해 있다는 기사를 접했습니다 굳이 아름다운 자연을 이유는 있는 파면시키고 당장 공사를 멈춰주세요
# 실제 요약문 : 막아주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  조선일보 일가 방용훈의 장자연 자살 사건과 자살 사건에 대해서 철저하게 특검을 바로 해서 바랍니다 문재인 정부는 마시고 반드시 바랍니다
# 실제 요약문 : 조선일보 특검 부탁합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  보통 1일 10일 하는데 2월 2월 4 있는 제대로 없는 이에 기존 2월 gt 2월 연장하여 주실것을 간곡히 청원드립니다
# 실제 요약문 : 연장을
# 예측 요약문 :  국회의원
#
#
# 원문 :  제대로 하기를 요청 합니다 그리고 좀더 바랍니다
# 실제 요약문 : 컬링 제대로 원합니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  광화문 동참합시다 고양이 식용금지 합법화해주세요 눈물로 호소합니다
# 실제 요약문 : 고양이 촛불집회
# 예측 요약문 :  국회의원
#
#
# 원문 :  강서구 pc방 살인사건 가해자의 신상을 청년이 무자비하게 죽었습니다 제발 부탁합니다 인권을 인권을
# 실제 요약문 : 강서구 pc방 살인사건의 가해자 신상
# 예측 요약문 :  자유한국당
#
#
# 원문 :  2017년 12월 19일 오후 경기에서 심판의 다양한 2 3 유리한 찬물을 되었습니다 네이버 다음 올해 최악의 그래서 책임을 묻고 강력 요구합니다
# 실제 요약문 : 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  진심으로 사과 했더니 사건이 그리고 회장 즉각 물러나라 잡고 폭행하고 이게 할짓입니까 폭행에 이래서 요즘 우리나라 갑질 아니면 폭행이 문제입니다 아는 누구든 다시 해야할 필요가
# 실제 요약문 : 회장
# 예측 요약문 :  국회의원
#
#
# 원문 :  교육부 장관 후보 대한민국 전문성이 편향된 사고를 가진 사람입니다 우리나라의 교육은 살아 있는 한다 도저히 마땅하다
# 실제 요약문 : 교육부장관 후보
# 예측 요약문 :  자유한국당
#
#
# 원문 :  이렇게 올려서 반대 어느 동의 해서 대통령님께서 있게 합시다 솔직히 저희 세금으로 갑질하는 사람들을 위해서 써야 하나요 대통령님 제발 부탁드리겠습니다 저희 세금을 엄한 곳에 쓰지 말고 진짜 우리 국민들을 위해서
# 실제 요약문 : 다산신도시 국민세금으로 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  합니다 그동안의 불구하고 무분별하게 생각이 듭니다
# 실제 요약문 : 사퇴시켜주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민 세금을 다산신도시 동영상 주민 보면 보면서 국민 세금으로 하나요 문제는 아파트 주민이 문제라고 생각 합니다 실버택배 지원 철회하세요
# 실제 요약문 : 다산신도시 실버택배 철회 하세요
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  이게 말이 됩니까
# 실제 요약문 : 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :
# 실제 요약문 : 엄벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  자동차 청원합니다 받고 못받고 하니 불만이 아닙니다 까지 골고루 청원합니다 그리고 10년 세금 같이 청원 합니다
# 실제 요약문 : 연장
# 예측 요약문 :  국회의원
#
#
# 원문 :  이재명지사와 사퇴를 촉구합니다
# 실제 요약문 : 이재명 은수미
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 삼성증권 지금까지 형태로 공매도를 없애야 한다고 생각합니다 이번기회에 없애 주시길 바랍니다
# 실제 요약문 : 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국 김정은 반대 청원합니다 저는 어떤 인간의 모릅니다 더구나 생각은
# 실제 요약문 : 김정은 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대통령이 가서 부부가 말을 했다고 합니다 청와대는 말을 대통령이 아니라 하고 사람도 대통령이 대통령이 애를 키우는 것도 아니고 함께 생각합니다 장관의 책임지고 모습을 바랍니다
# 실제 요약문 : 문재인 대통령
# 예측 요약문 :  자유한국당
#
#
# 원문 :  우리 나라의 미래 미래를 위하여 바로 사법부의 개혁을 위하여 못하고 일반 조차 이해할 없는 이재용 감형 판결한 정형식 판사의 특별 감사를 청원합니다
# 실제 요약문 : 정형식 판사
# 예측 요약문 :  국회의원
#
#
# 원문 :  보건복지부 다산신도시 지원을 반대합니다 입주민들의 위해 소중한 세금을 만약 그렇게 된다면 아주 안좋은 제2 제3의 빠진 다산신도시 주민들의 더러운 인해 국민 한명 소중하게 세금을 버리지 않길 바랍니다
# 실제 요약문 : 다산신도시 지원반대
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  안녕하세요 최근 특혜 박수진 아기 장기간 삼성병원 앞으로 대한민국의 아이들과 지금의 아이들이 돈과 권력 부당한 아픈 아이들과 국민들이 이상은 않게 죄가 있다면 엄중하게 처벌해주세요 위한 위대한 대한민국이 되길 바라며 청원합니다
# 실제 요약문 : 박수진 특혜 삼성 병원
# 예측 요약문 :  국회의원
#
#
# 원문 :  대주주 점점 주식 폐지해주세요 양도세 엄청난 있었습니다 정책을 그대로 하려 하는지 이해가 갑니다 부디 같은 길을 주세요 일본의 양도세 인한 아래 링크를 확인해주세요
# 실제 요약문 : 주식 전환 강력히 요청드립니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  합니다 대한민국 미래를 위해 청원합니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 박 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  최근 아닌 중국인 입국 시급합니다
# 실제 요약문 : 중국 입국 금지 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  공무원 군인 국민연금을 하라 국민이 국민연금을 공무원 군인 누구의 돈으로 그들의 연금을 국민들이 누구나 평등하게 있도록 강력하게 요청 합니다
# 실제 요약문 : 국민연금 폐지하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 기업이 기업들이 갑질을 끊임없이 하고있고 사법부는 부정부패 최저임금도 한번에 상식적으로 말이되나요 못한 국회의원이 국민의 연봉 2천만원 있을수 없습니다 국민 엄중한 바랍니다
# 실제 요약문 : 국회의원 연봉 삭감 발의
# 예측 요약문 :  국회의원
#
#
# 원문 :  없다 우리 기업 지켜주지 않는 나라도 없다 나라 망하게 공개 당장 철회하라 국민이 않을 것이다
# 실제 요약문 : 공개
# 예측 요약문 :  자유한국당
#
#
# 원문 :  확진자 명확하게 어느 병원에 있으며 입국 이동 어떻게 되나요 여기저기 대해서 못합니다 또한 그리고 있음에도 고의적으로 않은 사람들에게 벌금 강력한 조치를 해주셨으면 합니다
# 실제 요약문 : 우한폐렴 확진자
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :
# 실제 요약문 : 출산장려금
# 예측 요약문 :  국회의원
#
#
# 원문 :  손해를 삼성 는 청원을 올립니다 최저시급 피같은 손해를 마땅히 국민들 가슴에 국민들의 돈을
# 실제 요약문 : 국민연금
# 예측 요약문 :  국회의원
#
#
# 원문 :  아직도 절대로 안되는 사건 같은데 조치가 아닐까요
# 실제 요약문 : 폭행사건
# 예측 요약문 :  국회의원
#
#
# 원문 :  신분으로 나와서 성추행 말을 하는거 보면서 처벌해주세요
# 실제 요약문 : 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  의무 합법화해주세요 많은데 이게 어제 아니고 수술을 봅니다 언제까지 가족들이 피해를
# 실제 요약문 : 합법화해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  세금은 그런데 있는게 아닙니다 가족 아파트 주식 그리고 보험 대출 받고 만듭니다 이번 법적으로 아닙니다 세계 한국인 모두 세금으로 데리고 됩니까
# 실제 요약문 : 세금 지원 절대 안됩니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  로스쿨 폐지
# 실제 요약문 : 정시확대 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  깨끗한 대한민국 있는 문무일 검찰총장 당장 설명이 필요 없읍니다
# 실제 요약문 : 문무일 사퇴를 촉구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  남북 대한 내용이 너무 위험을 안고 있으니 우리 국민들이 정부 공개 동의 합니다
# 실제 요약문 : 대한
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 확진자가 이라고 30만 위험에 불안에 무엇이 올바른 묻고싶습니다
# 실제 요약문 : 코로나
# 예측 요약문 :  국회의원
#
#
# 원문 :  지명을 반드시 철회 되길 바랍니다
# 실제 요약문 : 유은혜 지명철회
# 예측 요약문 :  국회의원
#
#
# 원문 :  자리가 자리가 당연히
# 실제 요약문 : 파면 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  군인 연예인 단체 까지 코로나19에 모두 국민을 어찌 마음을 국민들의 세금 으로 세비를 받고 있는
# 실제 요약문 : 국회의원도
# 예측 요약문 :  국회의원
#
#
# 원문 :  우리는 말입니까 절대
# 실제 요약문 : 나향욱
# 예측 요약문 :  국회의원
#
#
# 원문 :  입니다 직원들에게 갑질하는 양 구속수사를 요청합니다 앞에 인권을 무시하는 수사를 바랍니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 위디스크 양 회장 구속 수사 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나로 인해 마스크 구매가 힘들고 가격이 너무 비쌉니다 정부에서 일괄 지역 맞게 합리적인 가격에 해주세요
# 실제 요약문 : 마스크 판매
# 예측 요약문 :  국회의원
#
#
# 원문 :  생계를 국회의원들은 그들의 만들고 자신들의 세비는 보면서 자신들이 얼마나
# 실제 요약문 : 국회의원
# 예측 요약문 :  국회의원
#
#
# 원문 :  저는 20 30분 다산신도시 1시간 넘게 있습니다 3기 신도시 건설 이에 만들어 편안하게 출퇴근 할수 있도록 지원 요청드립니다
# 실제 요약문 : 해결해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  간곡히 부탁드립니다 문재인대통령님 지금 어떤 않습니까 서울 서울 서민들을 3기 신도시 안되면 알고 하는거 같습니다 제발
# 실제 요약문 : 제발 살려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재까지 고려하여 지키는 군인이 아닌 경찰이 있는 걸로 알고 있습니다 2019년 8월 이후 일본은 한국의 아닌 이상 그런 필요 없다고 생각하며 직접 대한 진정한 합니다
# 실제 요약문 : 요청 드립니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  정부 지자체 방법 먼저 서울시 재난지원금 되었습니다 부디 다시 있게 감사하겠습니다
# 실제 요약문 : 서울시 재난지원금 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  자기 자식이 하지않고 우리 세금으로 진짜 없네요 나이에 당연히 그런데 가면 스스로 아닙니까 알고있는데 적어도 돈도 많은 사람들이 그렇게 모르겠네요 알아서 병원비
# 실제 요약문 : 뻔뻔한 그랜드캐년 사고 가족들
# 예측 요약문 :  국회의원
#
#
# 원문 :  혼자서 아빠 경우 아빠 할수 있도록 법을 바꿔주세요 어린이집도 보낼 없고 기타 등등 도움 받을 없습니다 도와주세요
# 실제 요약문 : 개정
# 예측 요약문 :  국회의원
#
#
# 원문 :  사건에 아이를 키우는 사람의 너무 가슴이 기가 막혀 글을 올립니다 비록 가해자들이 아무리 어린 하나 아무 없이 못한 피해자와 그의 어머니를 생각하면 도무지 없는 이에 부디 학생들의 엄중한 처벌을 청원하는 입니다
# 실제 요약문 : 인천 중학생 추락사 사건
# 예측 요약문 :  국회의원
#
#
# 원문 :  안녕하세요 이번 기대하고 기다렸는데 이전 사람은 안된다고 해서 너무 앞으로 최소 지원 없애야 하지 이제 너무 부탁드려요
# 실제 요약문 : 다시 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  궁금합니다
# 실제 요약문 : 보육교사 휴게시간
# 예측 요약문 :  국회의원
#
#
# 원문 :  제발 정부와 민주당 의원님들 가짜뉴스 여론조작 만들어 주세요 진실을 국가와 국민을 입니다 적폐 가짜뉴스 주세요
# 실제 요약문 : 가짜뉴스 여론조작 처벌법
# 예측 요약문 :  국회의원
#
#
# 원문 :  김기식 야당의 공격을 받아 결국 과연 김기식 문제를 야당의 국회의원들은 얼마나 알고싶습니다
# 실제 요약문 : 모든 해외출장 조사해주세요
# 예측 요약문 :  자유한국당
#
#
# 원문 :  수시 주십시요 공정하고 정의로운 나라를 위해
# 실제 요약문 : 수시 빨리
# 예측 요약문 :  대한항공
#
#
# 원문 :  아직도 생각을 갖고 있는 사람들이 많은 같습니다 직원들에게 폭언 폭행을 일삼고 사람의 인격을 짓밟는 백화점 처벌해 주세요 우리 사회 갑질 뿌리뽑아야 합니다
# 실제 요약문 : 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  김경수 조사 cctv 공개 합시다 청와대 김경수 협박 알면서도 경찰수사 이유를 밝혀야 합니다 알면서도 수사 청와대가 대한민국 국정운영 기가
# 실제 요약문 : 김경수 조사 cctv 공개 합시다
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  보고 법과 이걸 지금껏 믿고 검찰 지금껏 본인 수사 수사 윤석열 지금 않으면 국회에서 책임 당장 주십시요
# 실제 요약문 : 검찰 당장 파면해 주십시요
# 예측 요약문 :  국회의원
#
#
# 원문 :  수사하라
# 실제 요약문 : 한나라당 매크로 수사하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  문재인 대통령님 힘내세요 마세요 건강 존경합니다 지지합니다 평화의 반드시 대통령님 존경합니다
# 실제 요약문 : 문재인 대통령님 힘내세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국 국회 의원들이 평균 국민 가까이 받고 있고 한달 받습니다 하는 일에 비해 사람이 너무 많고 월급이 너무 국회의원 삶이 세금이 국회의원 수를 줄여주세요
# 실제 요약문 : 줄여주세요
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  확산 http news naver com read nhn mode lsd amp mid sec amp sid1 102 amp oid amp aid 이유로 이런 말이 됩니다 법적으로 해당 기관 등에 처벌 바랍니다 이것은 아니라
# 실제 요약문 : 여성 제도 폐지 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  막아주세요 하더라도 합니다
# 실제 요약문 : 금지시켜주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  주가가 지금 났습니다 이럴때 정부에서 그게 아니더라도 정말 개인 제발 부탁드립니다 수도권 힘들게 노력하는 제발 지금 대한 부탁드립니다
# 실제 요약문 : 주식시장 제발
# 예측 요약문 :  국회의원
#
#
# 원문 :  이어 지진이 났다고 합니다 같은 아주 다시 아닌가요 안전이 지금까지 투자한 상황을 있습니다 다시 한번 모든 국민을 위한 있도록 현명한 판단을 기대합니다 주민들의 안전과 모든
# 실제 요약문 : 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  민주당 사람입니다 이런 사람들이 당의 제가 먼저
# 실제 요약문 : 이재명과 은수미 시켜주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 동두천 어린이집 어린이집 차량을 이용해서 문제가 많습니다 아이들 이용한 사용해서 어쩔 없다고 하고 합니다 이것은 법적으로 한다고 생각합니다 최소 다수의 이용하는 아이들을 있어야 한다고 생각합니다
# 실제 요약문 : 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  항상 20만명 넘는 답변 채우고 까지 기다리고 답변을 하던데 답변을 있다는게 말이됩니까 요즘 사회적 이슈가 되는 청원은 20만명 청원 않다고 봅니다 난민 동의를 20만명 답변 바랍니다
# 실제 요약문 : 제주도 돌파
# 예측 요약문 :  국회의원
#
#
# 원문 :  청원 받도록 해주십시요 현재 부담이 못하고 다시 밖에 같습니다 부디 서민을 위해 이제 현실에 살기가 입니다
# 실제 요약문 : 10년 해주십시요
# 예측 요약문 :  국회의원
#
#
# 원문 :  kbs 9시 뉴스에서 김학의 사건 피해 여성이 나와서 했습니다 얼마나 제가 눈물이 특히 피해자는 최소 합니다 밑에 볼수 있을겁니다 검찰 경찰 수사는 믿을 수가 없습니다 그러므로 반드시 특검을 요구합니다
# 실제 요약문 : 김학의 사건 특검을 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  정치 기가 본인 문제인지 한국당 조작 수사 바랍니다
# 실제 요약문 : 한국당
# 예측 요약문 :  국회의원
#
#
# 원문 :  아이를 간절히 시험관 다시 했는데 건강보험 기다렸는데 ㅠㅠ ㅠㅠ 제한 안될까요 간절히 부탁드립니다 ㅜㅜ
# 실제 요약문 : 제한 풀어주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :
# 실제 요약문 : 우롱하는
# 예측 요약문 :  국회의원
#
#
# 원문 :  공격을 당해 있는데 하지않고 사과도 하지않고 벌금 조금 때문입니다 솜방망이 처벌 덕분에 않고 정말 하지 않고 다니는 강력한 처벌을 해주세요 다시는 개를 못하게 해주세요
# 실제 요약문 : 강화해주세요
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  이재용 집행유예 정형식 판사 특별 감사 바랍니다
# 실제 요약문 : 이재용 집행유예 정형식 판사 특별 감사 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  취소해주세요
# 실제 요약문 : 취소해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  4월 선거 선거에서 위해 창원 막고 도로를 투표를 사건입니다 철저한 범죄를 명명백백 밝혀주십시요
# 실제 요약문 : 사건 촉구합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  이것은 아니고 정부가 가만히 무지한 말을 가만히 있으니 돈을 있습니다 정부는 이런 불합리한 제도 문재인대통령님 부탁드립니다 http v media daum net v rcmd rn
# 실제 요약문 : 없애주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  것에 대해 있습니다 본인 스스로 책임지고 하는것이 마땅하다고 봅니다 대부분의 오히려 받고 하는 것처럼 정책을 합니다 그리고 모든 정책을 실명을 밝혀서 스스로 없애는 가장 생각합니다
# 실제 요약문 : 원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  불쌍한 우리 세월호 학생들 편히 있게 나쁜 놈들 조여옥 대위 처벌해주세요 입니다
# 실제 요약문 : 세월호 조여옥 대위 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민은 공정한 원한다
# 실제 요약문 : tv조선 허가 취소
# 예측 요약문 :  국회의원
#
#
# 원문 :  https n news naver com article 민주당 고발합니다
# 실제 요약문 : 고발
# 예측 요약문 :  국회의원
#
#
# 원문 :  피드백을 요구합니다 현재 언론에 쓰는 우익 일본 방탄소년단의 그걸 제2의 방탄소년단 하는 모습 상당히 어이가 없습니다 제발
# 실제 요약문 : 피드백을 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  아파트 늦게 폭행한 사람 필요합니다 그리고 와서 폭행 했다고 하던데 이게 사실이라면 처벌이 반드시 필요합니다 사람 입니다 그냥 넘어가서는 본보기로 강력히 필요 합니다
# 실제 요약문 : 아파트 경비원 합시다
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민의 한사람으로써 조국 청문회 빨리 보고싶습니다 청문회
# 실제 요약문 : 청문회
# 예측 요약문 :  대한항공
#
#
# 원문 :  천안함 정확한 원인을
# 실제 요약문 : 천안함 재조사해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  이재명 대한 관련 이제 명명백백 또다시 허위사실 매일 이들을 부디 대한민국을 만들어 주세요ㆍ
# 실제 요약문 : 구속해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  매년 지원금을 받고 있는 합니다 지원금을 받는 유일한 합니다 사실에 뉴스를 사실을 하는 등의 못한 많다고 이야기 하는 분들이 많습니다 사실이 그렇다면 부분이 관련 책임 의해 책임을 정부 이상 것입니다
# 실제 요약문 : 연합뉴스
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  음주운전 행위는 살인죄로 주시길 바랍니다 음주운전으로 인하여 있습니다 제발 감형 없는 음주운전 처벌을 강력하게 원합니다
# 실제 요약문 : 살인죄로
# 예측 요약문 :  국회의원
#
#
# 원문 :  국회 피감기관의 지원을 받은 전 국회의원 국회의원의 정치 밝혀 판단을 받아 결과를 투명하게 공개해 주시기바랍니다
# 실제 요약문 : 국회의원 전수조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  국회의원들이 입법을 해야하는 있습니다 우리 사회의 가장 생각합니다 일하지 않는 국회의원 주지 것을 강력히 주장합니다
# 실제 요약문 : 국회 의원의 무노동 무임금 적용
# 예측 요약문 :  국회의원
#
#
# 원문 :  남성의 남성은 여성의 이를 이용할 있도록 청원하는 바입니다
# 실제 요약문 : 있도록 해주십시오
# 예측 요약문 :  국회의원
#
#
# 원문 :  평가인증 어린이집 아동 담당 서류 여러가지 인해 매번 어린 아이를 키우는 여러가지 있는 현실입니다 어린이집 평가인증 폐지 청원 합니다
# 실제 요약문 : 어린이집 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  https m news naver com nhn amp oid amp aid amp cid amp sid1 102 amp amp amp 언제까지 하겠습니까 여러분 주십시요
# 실제 요약문 : 살려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  내용이 필요 없을 합니다 국회의원 연봉을 국민 수준으로 청와대가 국민청원을 통해 국민의 합니다 청와대가 아니라고 봅니다 국민은 주었습니다 국민의 마음을 의지가 있다면 청원 되길 바랍니다
# 실제 요약문 : 국회의원 연봉을 국민
# 예측 요약문 :  국회의원
#
#
# 원문 :  https naver com 20년동안 불구하고 개인이 있는 위해 있는 위해 한번 해당 대한 지원을 해주셨으면 합니다 평생 많은 도움을 지원이 좋겠습니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 지원해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  도끼 세무조사 요청합니다 보았습니다 세금을 알고싶습니다 서민을 우롱하고 우롱하는
# 실제 요약문 : 도끼 세무조사 요청합니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  나경원의 남편 판사가 사건에 대하여 검찰에 요청하는 했다고 사건과 윤석열 장모 재판 보이는 사건에 대하여 재수사 바랍니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 나경원 남편 판사 탄핵 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  국회의원이 피감기관 비용으로 해외출장 전수 조사 요청합니다 동시에 국회의 출장 국민의 세금이 제대로 것을 요청합니다 나아가 대해서도 기준을 세금이 않도록 개정 요청합니다
# 실제 요약문 : 국회의원 해외출장 전수조사 청원
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  증권사 통하여 조작하고 개인 만듭니다 당할 밖에 없습니다 이런 외국계 지속적으로 국내 이들에게 강력한 필요합니다
# 실제 요약문 : 증권사 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  지금 같은 내용의 청원이 너무 많습니다 손을 쓰고 아래 제가 대한항공 명칭 회수 조현아 조현민 gt https www1 president go kr petitions 198071 좋겠네요 것도 그렇고 청와대 이리
# 실제 요약문 : 대한항공 명칭변경 조현민 한곳으로
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  바로 당신이 뽑은 매달 국민 혈세를 노무현 대통령을 하지 말고 당당히
# 실제 요약문 : 나경원 이번 책임지고 당장
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국 국민의 이름으로 해임 되기를 청원합니다 전에 우리 정부가 교수를 미국 정부가 것처럼 대한민국 정부는 대한민국 국민을 모욕하는 하여 이상 보지 않게 주실 것을 정중히 청원합니다
# 실제 요약문 : 청원
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  강원도 전체 전체 지급 30 1인당 전체 1인당 10 전체 말고 똑같이 지원해주세요 1인당 지급 다른 어려운 사람들은 받을수 없어요 이라도 지원해주세요
# 실제 요약문 : 강원도 코로나 19 지원금 전체 지급
# 예측 요약문 :  국회의원
#
#
# 원문 :  권력에 억울한 없어야 합니다 장자연 사건 재수사 청원합니다
# 실제 요약문 : 장자연 사건 재수사 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  금감원의 강화를 청원합니다 지속적인 일명 고통을 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 의 부탁드립니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  마스크를 보낼수 있어 중국 있네요 맘대로 사는 마스크 아이 맘대로 못하는 현실이 답답합니다 최소한 있게 주시기 바랍니다
# 실제 요약문 : 해외 가족 마스크 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  종교의 자유가 있는 대한민국 에서 현재 강제개종 하려고 하다가 생명을 잃은 일이 일어나고 있습니다 대통령님 진상을 자세히 강제개종 주시길 간절히 부탁드립니다
# 실제 요약문 : 강제개종 금지법 제정
# 예측 요약문 :  자유한국당
#
#
# 원문 :  이번에 발생한 자유한국당 의원에 대한 체포동의안이 계기로 비리 국회의원의 되고 있는 불체포특권을
# 실제 요약문 : 국회의원 불체포특권 폐지
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재 각종 논란이 되고 있으며 댓글 국민들을 훼손한 더불어민주당 김경수 일명 댓글조작 사건과 대한 이루어져야 합니다 이를 계기로 진정한 적폐가 낱낱이 청산 있도록 부탁드립니다
# 실제 요약문 : 김경수 청원합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  일본에 아파트 자식은
# 실제 요약문 : 후보자
# 예측 요약문 :  국회의원
#
#
# 원문 :  일본이 합니다 이건 국가 문제입니다 정치적 경제적으로 무조건 막아주세요 우리 아이들의 미래를 지켜주세요
# 실제 요약문 : 막아주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  시대가 어느시대인데 인터넷 중국처럼 https 관련 청원 청와대 https http 없어지고 이제는 청와대 이게 자유민주주의 국가가 맞나요
# 실제 요약문 : https
# 예측 요약문 :  국회의원
#
#
# 원문 :  조현아 대한민국은 사람만 있는
# 실제 요약문 : 조현아 재조사 박창진 보호해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  해외에서 사례가 나왔습니다 선거 있을 우려가 있다고 봅니다 이번 수개표로 해주셨으면 합니다 없는 깨끗한 사회 만들어 주세요
# 실제 요약문 : 지방선거 수개표 드립니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민을 개 하던 제가 개 세금을 내야 하는 겁니까 세금이 알면서도 반대 합니다 국민을 개 돼지로 보는 국민의 세금으로 월급을 준다는 말이 되지 않습니다 국민들에게 세금을 마십시오 우리는 개 돼지가 아닙니다
# 실제 요약문 : 개 돼지 세금
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  방송 '그것이 청원합니다 학생이 성폭행을 자살을 뻔뻔하게 아무런 책임이 같은 보이는 교장 사형 좋겠습니다
# 실제 요약문 : 청원합니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  공매도 아닙니까 소중한 공매도
# 실제 요약문 : 주식시장 공매도 전면 폐지
# 예측 요약문 :  국회의원
#
#
# 원문 :  저는 우리나라의 경우 아이가 대통령님 특별법을 법을
# 실제 요약문 : 특별법을
# 예측 요약문 :  국회의원
#
#
# 원문 :  이슬람 난민을 시켜주세요 난민을 전혀 하지 국민 생명과 안전을 바랍니다 리비아 이란 예멘
# 실제 요약문 : 아니라 이슬람 입국금지 시켜주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 일어난 일입니다 주민의 말을 하는데 분노가 국민을 되지 않아 이제 국민이 그리 생각하는 않는 의원을 즉각 해주세요
# 실제 요약문 : 사퇴를 촉구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  공기청정기가 있는 있고 없는 있는 것이 부모 입장에서 너무 불안합니다 심지어 공기청정기 현재 미세먼지 문제가 심각한데 아이들한테 조금이라도 있도록 도와주세요
# 실제 요약문 : 유치원 공기청정기 의무화 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대통령님 조현민 드라마 갑질하는 내용을 필요가 있다고 봅니다 젊은 사람 그런 화가납니다 드라마 일어났습니다 드라마 인한 아닐까 대해서는 사회적 조치를
# 실제 요약문 : 대한항공
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나 많은 없었고 지금도 확진자 계속 당해 정치적으로 코로나로 국민의 목소리로 반대 청원 합니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 코로나 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  조선일보 부인 자살사건 재조사
# 실제 요약문 : 조선일보 이미란 자살 관련 재수사
# 예측 요약문 :  국회의원
#
#
# 원문 :  지난 이전에 들어간 막대한 예산을 있습니다 그리고 그당시 있었는지 의문입니다 해야하는 어려운 시기에 예산이 있다면 코로나로 어려운 서민들을 쓰는게 맞다고 생각합니다
# 실제 요약문 : 추진
# 예측 요약문 :  국회의원
#
#
# 원문 :  때는 않고 구속 중단하라 즉각
# 실제 요약문 : 김경수 구속 즉각
# 예측 요약문 :  국회의원
#
#
# 원문 :  4 6 sbs 그것이 알고 전명규 교수를 보고 개탄을 없었습니다 본인의 위하여 방법을 않고 막는 전명규 교수는 당연히 파면을 해야된다고 생각합니다
# 실제 요약문 : 교수 전명규 교수 파면을 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  518 대한 의문이 점점 있습니다 518 국가유공자 명단을 그런 하지 않을 생각합니다 내가 국민 세금이 어떻게 대해서 권리가 있습니다
# 실제 요약문 : 518 국가유공자 공개 요청합니다
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  일부 편파적인 합니다 일부 단지 주민의 잘못을 다른 국민이 책임 합니까 모든 아파트에 이게 인지 모르겠네요
# 실제 요약문 : 다산신도시 실버택배 철회
# 예측 요약문 :  국회의원
#
#
# 원문 :  수사는 어디서 어떻게든 성폭력을 피해자가 제발 간절히 해주세요
# 실제 요약문 : 조재현 수사
# 예측 요약문 :  국회의원
#
#
# 원문 :  있습니다 개인 근데 수수료 하루에 있습니다 수수료 아닌가요 이런 거래소 때문에 수많은 거래 보고 있습니다 정부에서 해주세요
# 실제 요약문 : 같은 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  버닝썬 승리 정준영 등의 여러가지 일이 바람에 장자연 사건이 있습니다 장자연 사건이 않도록 이상 제2 장자연 사건이 나오지 않도록 해주세요 그리고 무엇보다 장자연 사건을 도움을 주고 계시는 윤지오 씨의 신변보호를 보다 강화해주세요
# 실제 요약문 : 장자연 사건 말아주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나 바이러스가 중국에서 저희 국민들은 최대한 개인 바이러스가 막기위해 그런데 신천지 행동으로 대한민국 국민들이 위협을 바이러스를 그런데 아니라 다시한번 다수 국민들의 세금이 않도록
# 실제 요약문 : 신천지 지원 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  법은 정치적 판단을 한다는건 자리에 맞지 않다고 봅니다 그리고 국회의원 관련되어 수사가 제대로 되지않고 국민들을 더욱 주는 사건을
# 실제 요약문 : 문무일 특검 요구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공 조현민 갑질이 국민에 한사람으로써 도저히 두고 볼수 없을 분노를 느낍니다 대한이란 이름을 삭제 하여 주십시요 이름으로 나라 망신 같아 참을수가 없습니다
# 실제 요약문 : 대한 이름을 삭제 해주십시요
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민들이 가면 같이 정부 모르고 해서 보면 되는 이런 현실이 너무 전액 국민이 반드시 국민이 결정 있도록 하라 이건 국민들의 명령이다
# 실제 요약문 : 국민연금
# 예측 요약문 :  국회의원
#
#
# 원문 :  대통령님의 아동수당 경제적 열심히 살아가는 평범한 30대 맞벌이 이유로 않고 꼬박꼬박 열심히 있습니다 받아 다시 피눈물 국가에 세금을 공약 지켜주십시오
# 실제 요약문 : 아동수당
# 예측 요약문 :  국회의원
#
#
# 원문 :  유은혜 교육부장관 여성 교육부장관 유은혜 교육부 장관 적극
# 실제 요약문 : 지지합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  제발 국민으로서 너무 싫습니다 제발 안전이 국민들은 너무 공포에 제발 부탁입니다
# 실제 요약문 : 제발 포항
# 예측 요약문 :  국회의원
#
#
# 원문 :  단일팀 반대합니다 아닌 같습니다 이건 선수들의 생각합니다 달고 선수들이 뛰는 모습이 국민들에게 같습니다 오는 것은 반대합니다
# 실제 요약문 : 평창올림픽 반대
# 예측 요약문 :  국회의원
#
#
# 원문 :  동물학대 만행을 저지른 양 강력한 나라를 바로 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 세무조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  안되면 없고 식으로 한순간에 생각합니다 20년 그래야 생각합니다
# 실제 요약문 : 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국의 정체성을 사람입니다 군사 국가를 자신의 대상이 되었습니다 국민의 개인의 인간의 절대로 훈장을 됩니다 똑바로 하세요 줘야 하나요
# 실제 요약문 : 훈장을
# 예측 요약문 :  국회의원
#
#
# 원문 :  정형식을
# 실제 요약문 : 정형식 파면
# 예측 요약문 :  국회의원
#
#
# 원문 :  친일파 없고 보장해주세요
# 실제 요약문 : 파면
# 예측 요약문 :  국회의원
#
#
# 원문 :  제주도에 이슬람 반대합니다
# 실제 요약문 : 제주도 예멘 난민 이슬람
# 예측 요약문 :  국회의원
#
#
# 원문 :  비쌉니다 내려주세요
# 실제 요약문 : 통행료 인하
# 예측 요약문 :  국회의원
#
#
# 원문 :  김기식 한다고 본다
# 실제 요약문 : 국회의원 해외출장 전수 조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  유은혜 교육부 장관 임명 당장 철회 시켜주세요 저런 여자가 어떻게 교육부 장관을
# 실제 요약문 : 대통령님께 부탁드립니다 유은혜 임명 철회 해주세요
# 예측 요약문 :  자유한국당
#
#
# 원문 :  그것이 알고 보고도 아무런 이슈가 되지 않는 나라가 자신의 위해 많은 죽음으로 악마를 제명 되기를 청원합니다
# 실제 요약문 : 전명규 빙상연맹 퇴출 청원 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  동물을 상대로 하는 것은 범죄입니다 사람만 소중한 아닙니다 모두 소중한 그런데 몇몇 사람들은 동물 합니다 사람을 상대로 동물 된다는 것은 등의 위험한 하다가 다치거나 합니다 동물 하지 못하게 하는 법을 만들어주세요
# 실제 요약문 : 반대
# 예측 요약문 :  국회의원
#
#
# 원문 :  집단폭행사건 너무 무섭고 미래가 걱정됩니다 다시는 이런 반복되지 않도록 엄중한 처벌을
# 실제 요약문 : 광주폭행 엄벌을 처해주세요
# 예측 요약문 :  대한항공
#
#
# 원문 :  태풍 솔릭이 한반도를 합니다 정부가 신속히 임시 지정해서 아이들은 어린이집 사고를 당하는 일이 없도록 아이가 무사히 학교 등을 있는지 일이 없도록 재산이 피해를 않도록 혹시 모르는 있도록 해주세요
# 실제 요약문 : 태풍 8월 지정해주세요
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  보면서 너무 생각 경기에서 너무 정말 모르겠습니다 국민들이 국가 대표가 보고 희망을 그만큼 꿈을 짓밟는 것입니다 제발 처벌을 부탁드립니다
# 실제 요약문 : 김보름 박지우 아닌 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  추미애 청와대에 대해 분노합니다 강력히 규탄하며 반대합니다 이해찬 사퇴를 강력히 촉구합니다 해체하고 강력히 요구합니다
# 실제 요약문 : 더불어민주당 법무부장관 후보 강력하게
# 예측 요약문 :  국회의원
#
#
# 원문 :  세상에 진실이 않는 일은 없습니다 다들 알고 있는데 정치권에서 모르고 있다니 밝혀주시기 바랍니다 나라의 일을
# 실제 요약문 : 이재명 은수미
# 예측 요약문 :  국회의원
#
#
# 원문 :  자기가 관리 못해서 생긴 일인데 마음 되는 어떻게 실수로
# 실제 요약문 : 고발합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  권력을 위해 만든 법이 지들 국민도 알권리가 있다 그리고 이제는 국회의원은
# 실제 요약문 : 체포동의안
# 예측 요약문 :  국회의원
#
#
# 원문 :  조여옥대위 처벌 하세요
# 실제 요약문 : 조여옥대위 처벌 원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  일하는 사람입니다 조치를 않았는데 등은 되었는데 않아 운영이 어려워 문을 많이 이용 제한 조치를 형평성에 맞게 주시기 바랍니다
# 실제 요약문 : 합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  대한항공 나라망신 아닙니까 어디서 대한이라는 이름을 줍니까 이름 해주세요 좋은 이름 않습니까 정말 부끄럽습니다 대한항공
# 실제 요약문 : 대한항공 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  매년 항상 뉴스 되고 있습니다 단속을 하더라도 처벌이 하는것 없도록 강력한 바랍니다 뉴스 링크 참고 하세요
# 실제 요약문 : 강력 단속 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  동일한 수준으로 있습니다 그러한 업체 동의를 않으면 있습니다 어떻게 그렇게 백화점 전체에 대한 조사가 필요합니다
# 실제 요약문 : 대해서
# 예측 요약문 :  국회의원
#
#
# 원문 :  매우 시간을 인정 받고 있지 자유롭게 못하고 오히려 매우 제도는 8시간 지금 맞는 아닐까 생각이 들어 청원합니다
# 실제 요약문 : 보육교사
# 예측 요약문 :  국회의원
#
#
# 원문 :  시험을 생각됩니다 서울 경기 인천 지역의 많고 많습니다 3 아니라 미리 관련한 답변을
# 실제 요약문 : 연기
# 예측 요약문 :  국회의원
#
#
# 원문 :  이게 무슨 모든 것에 어떻게 합니까 그에 판단 내려 주시길 바랍니다 저희 나라가 입니까
# 실제 요약문 : 주식
# 예측 요약문 :  국회의원
#
#
# 원문 :  미성년자 신상공개 해주세요
# 실제 요약문 : 신상공개 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  쓸모없는 집단 여성가족부 예산 정작 자신들이 하는지 아무것도 모르는 그냥 세금 낭비 여성가족부 폐지 여성가족부 업무를 해야 하는지 자신들 모르고 세금 국민들 스트레스 주는 동의 해서 이참에 아예 여성가족부 지금 우리 힘들어합니다
# 실제 요약문 : 여성가족부 폐지 합시다
# 예측 요약문 :  국회의원
#
#
# 원문 :  회사 게시판에 댓글을 이유로 댓글을 올린 폭행한 양 강력 것을 부탁드립니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 위디스크 양 강력처벌 것을 부탁드립니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  가족들이 버젓이 방송에서 마땅히 피해자를 가족 강력 원합니다
# 실제 요약문 : 방송퇴출
# 예측 요약문 :  자유한국당
#
#
# 원문 :  조여옥대위 해임을 청원합니다 청문회에서 조차 뻔뻔하게 일삼은 징계를 생각합니다
# 실제 요약문 : 청원합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  안될 한나라당 수많은 그리 한나라당 관련 새누리당 현 자한당 댓글 합니다 자유한국당의 만행을 특검으로 낱낱이 청원합니다
# 실제 요약문 : 한나라당 특검 청원
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  분당선 줄이고 주기를 희망합니다 또는 연장하여 있도록 조치 바랍니다
# 실제 요약문 : 분당선 조정 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  오늘 성폭행한 파렴치한 인간이 징역 왜 제발 범죄 엄하게 부탁드립니다
# 실제 요약문 : 올려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  폭염으로 더운 날씨에 에어컨 어떻게 이게 말이 됩니까 전기료 누진세 폐지 해주세요 바꿔야 합니다
# 실제 요약문 : 전기료 누진세 폐지 요청합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  인간이 아닙니다 저지른 죄는 엄하게 해주십시오 이런
# 실제 요약문 : 절대 안됩니다 미성년자 처벌해야합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  단순 폭행이 아니라 사람이 있었던 전원 강력한 제2 제3의 피해자를 막을 있습니다 대한민국을 살아가는 국민들이 돈 법이 알게 해주셨으면 합니다
# 실제 요약문 : 광주폭행 강력한 처벌을 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  정치적 혼란을 대한민국의 행사를 국민을 진행 국민을 했다 해결 주십시요
# 실제 요약문 : 나경원 파면해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  어린이집 보육교사의 보면 아이들 어린이집 교사의 요청합니다
# 실제 요약문 : 대한 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  안녕하십니까 우리 함께 화가 존경합니다 의 뜻을 행위입니다 페이스북 합니다 피가 모욕 행위를 확신합니다 일단 페이스북 보세요 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 처벌을 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  그것이 알고싶다 대한 확인하고 국민의 사람으로서 청원합니다 인권 대한 정부 사과를 것을 청원합니다 그들이 마땅히 받아야 대한 이루어져야 것입니다
# 실제 요약문 : 대한
# 예측 요약문 :  국회의원
#
#
# 원문 :  본인이 국가에서 만약에 일이 발생합니다 본인들이 세금은 그리고 만들어주세요
# 실제 요약문 : 내려주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한 민국 이라는 들어간 있습니다 대한항공 입니다 하지만 그들은 땅콩회항 부터 대한 문제를 일으키고 있습니다 다른 이름은 대한민국의 국호를 해서 우리나라의 떨어지고 있습니다 대한민국의 어느 회사에서 쓸수 있는 이름이 아닙니다 해주세요
# 실제 요약문 : 대한항공 이름 못쓰게 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공이 조현아 해서 계속 이런 사건이 있고 현재 있고 많은 인해 근로자 있는데 얼마나 깨끗한 세무조사 한번 국민들이 같습니다
# 실제 요약문 : 대한항공 세무조사 실시 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  안희정 성폭력 사건의 철저한 수사를 요청합니다 또한 결과를 국민들께
# 실제 요약문 : 안희정 성폭력 사건 철저한 수사 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  염순덕 살인사건 사건으로 하지만 유가족을 위해서라도 재조사 부탁드립니다
# 실제 요약문 : 염순덕 살인사건 재조사 부탁드립니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  인천에 들어온 어찌 아예 이나라를 자국민이 그보다 무엇입니까 차별금지법 반대 해체 난민법 무비자 폐지 해주세요 국민의 않는 정치인들
# 실제 요약문 : 인천 나라 반대
# 예측 요약문 :  국회의원
#
#
# 원문 :  안녕하세요 국회의원 해외출장 전수 조사 요청합니다
# 실제 요약문 : 국회의원 해외출장 전수 조사 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  어떻게 말로 이들의 있겠습니까 온국민이 하는게 마음이
# 실제 요약문 : tv조선
# 예측 요약문 :  국회의원
#
#
# 원문 :  대상으로 보험료 증거 인한 판정을 철회해주세요
# 실제 요약문 : 장애인 구속해주세요
# 예측 요약문 :  대한항공
#
#
# 원문 :  임대 제도를 전면 폐지해주세요 pd수첩 기타 보면 집을 가지고 있고 집을 가지고 또다시 대출을 받아서 매달 집을 있습니다 지금 당장 제도를 폐지
# 실제 요약문 : 전면 폐지해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  재난 안전 관련 우리를 역시 저희의 국가의 국민의 역시 국민이 꾸준히 서비스
# 실제 요약문 : 중단 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  여 버린 해서는 국가적 위상을 여자를 절대 안된다 이에
# 실제 요약문 : 나경원을 파면해 주세요
# 예측 요약문 :  대한항공
#
#
# 원문 :  현재 논란이 있습니다 영상을 cctv가 있었습니다 문재인 까지 영상을 국민들에게 공개하여 문재인 백신 가짜 바랍니다 부탁드립니다 국민들이 이런걸 가지고 서로 싸우고 있습니다 하루 빨리 논란을
# 실제 요약문 : 문재인
# 예측 요약문 :  국회의원
#
#
# 원문 :  성민이 사건 가해자 얼굴 공개 촉구합니다 얼굴공개 촉구합니다
# 실제 요약문 : 가해자 촉구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  가격이 너무 합니다
# 실제 요약문 : 주십시요
# 예측 요약문 :  국회의원
#
#
# 원문 :  https www1 president go kr petitions page
# 실제 요약문 : 서울 아이들을
# 예측 요약문 :  국회의원
#
#
# 원문 :  회사 조사해서
# 실제 요약문 : 갑질
# 예측 요약문 :  국회의원
#
#
# 원문 :  조여옥대위 위증 청원합니다
# 실제 요약문 : 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  우리나라 국민들을 먼저 국민들 세금으로 제대로된 아이들을 먼저 한달에 최대 정말 생각합니다 계속 이렇게 나중에
# 실제 요약문 : 제주도 예멘난민 추방
# 예측 요약문 :  국회의원
#
#
# 원문 :  20대 국회가 운영되는 것을 보니 우리나라 국회의원은 국민을 대표하는 커녕 그냥 개인적 뿐입니다 그러므로 청원하는 바입니다
# 실제 요약문 : 조기총선 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  학대 대한 처벌을 대상으로 처벌이 강력한 처벌을 통해서 다시는 일어나지 않도록 해주세요 없다면 사회에서 격리시켜주세요 더이상 일이 합니다
# 실제 요약문 : 성범죄 청원합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  우리 외국인 자격 있다는 규정 존재합니다 조현민 적용이 현재 대한민국 아닌 부디 엄격히 적용하여 당장 유사한 바랍니다
# 실제 요약문 : 대한항공 조현민 전무
# 예측 요약문 :  국회의원
#
#
# 원문 :  신천지 코로나19 원인 가운데 있고 국가의 있습니다 그럼에도 불구하고 명단과 뉴스를 많이 접하고 있습니다 있는 행동으로 국가와 국민에게 손실을 있는 통하여 국민들께 알리고 처벌과 청원합니다
# 실제 요약문 : 신천지 요청합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  문재인 군사 때문에 죽은 어린 못하고 안타까운 일이 병원에 그래도 있지 마음이 너무 아프네요 내년 군대 가는 아들을 정말 화가나네요 이런일이 무섭고 책임을 지고 물어보고 싶네요 왜
# 실제 요약문 : 양구군인
# 예측 요약문 :  국회의원
#
#
# 원문 :  보건복지부 후보 혐의로 실형을 받고 그런데 대한민국의 아이들의 교육을 있는 대한민국에서 거의 국민들의 권리를 같습니다 조속히 특검을 하고 하여 의혹을 바랍니다
# 실제 요약문 : 아들 마약
# 예측 요약문 :  자유한국당
#
#
# 원문 :  수원 인구가 고양 용인 창원 인구가 넘는 지정해주세요
# 실제 요약문 : 수원 고양 용인 창원 특례시
# 예측 요약문 :  자유한국당
#
#
# 원문 :  세월호 진상규명을 청원합니다
# 실제 요약문 : 세월호 진상규명
# 예측 요약문 :  국회의원
#
#
# 원문 :  세월호 위증을 하여 법을 위반 처벌해주시기 바랍니다 그것도 나라와 국민을 지켜야 신분 행동입니다
# 실제 요약문 : 조여옥대위 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국 주변 일본 북한 중국 부터 당하고 자신들의 하고있는 이상한 나라 까지 있습니다 가진 부터 대한민국의 위해서는 즉각 합니다
# 실제 요약문 : 즉각 시켜 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  피해자에게 피해자들을 몰고 기만하는 뻔뻔한 가해자들을 대한민국 국민으로써 아무 그저 억울한 상황을 더이상 피해자가 잘사는 나라 가해자는 나라 그런
# 실제 요약문 : 거제 엄벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  시급 대해서는 공무원 연봉 인상에 따른 국회의원 2천만원 뭔지 나가는 것도 말이 안된다고 2천만원 말이됩니까 2천만원 사람들이 많습니다 진정 국회의원이 하는 누구 마음대로 인상을 하나요 반대로 삭감 청원합니다
# 실제 요약문 : 국회의원 삭감 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  폐지해야 합니다 지금 거기에 중국인 아주 자국민 안전은 폐지해야 합니다 난민법 저들을 없습니다 난민법 폐지를 해야 있는 정부와 하루빨리 난민법 저들을 다시 국민들의 손으로
# 실제 요약문 : 아니라 난민법 폐지를 위해 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  연일 보도 되고 있는 보도를 보면 화가 치밀어 이젠 없고 됩니다 인터넷에 내용을 청소년들이 진실은 않습니다 제발 건강한 국민의 주세요 제발 보도를 시켜 주세요
# 실제 요약문 : 청원합니다
# 예측 요약문 :  자유한국당
#
#
# 원문 :  입국을 거부합니다 대한민국 이땅에 그리고 현재 위해서라도 부탁드립니다
# 실제 요약문 : 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재의 국회의원 못합니다 대통령 탄핵을 했지만 1년이 지난 지금도 국회의원 없고 앞으로 해도 발목만 잡고 가는 계속 생각 합니다 무노동 무임금 일하지 말라
# 실제 요약문 : 탄핵 그리고 국회해산 으로 조기총선
# 예측 요약문 :  국회의원
#
#
# 원문 :  여성 목소리를 듣고 여성 인생을 보호하기 위한 많은 이용하여 무고한 남성을 다수의 여성들이 사건입니다 다스려 주십시오
# 실제 요약문 : 성범죄 조작 사건 무고죄 엄벌 적용
# 예측 요약문 :  국회의원
#
#
# 원문 :  화장실 있게 있는 유튜브 방송 해주세요 전세계 국민을 진심으로 하는지 봅시다
# 실제 요약문 : 김성태 단식농성 유튜브 해주세요 국민
# 예측 요약문 :  국회의원
#
#
# 원문 :  생명을 담보로 있는 각종 최순실 정유라 보다 하네요 목숨을 가지고 이번 사건 철저히 진상규명 해주세요
# 실제 요약문 : 삼성병원
# 예측 요약문 :  국회의원
#
#
# 원문 :  언론인 정치인 방송인 등등 사람들에게 당하고 있는 개인 목소리에 과거 그녀의 행동 목적이 문제를 해결하는 과정에서 너무 많은 계십니다 권력에 의한 있었다면 그녀의 이야기를 믿고 곳이
# 실제 요약문 : 주세요
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  설치해주세요
# 실제 요약문 : 세종시에 설치해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  보고 한달에 많이 있습니다 자국민의 부담을 혜택을 대한민국은 국제적 제발 외국인 건강보험 혜택 다른 외국인
# 실제 요약문 : 외국인 없애주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  공인중개사 현재 이르렀습니다 인원을 주시기를 바랍니다
# 실제 요약문 : 공인중개사 자격 제한
# 예측 요약문 :  국회의원
#
#
# 원문 :  조선일보를 당장 방용훈의 부인 경찰 검사 판사를 당장 바랍니다 또한 방용훈 일가를 것을 요청합니다
# 실제 요약문 : 구속하라
# 예측 요약문 :  대한항공
#
#
# 원문 :  한나라당 청원글이 다른 계속 있어 새로운 청원 글이 동의 의견이 있습니다 한나라당 매크로 동의 의견이 가장 많은 의견 국민의 힘을 보여줍시다
# 실제 요약문 : 한나라당 메크로 청원
# 예측 요약문 :  나경원 의원
#
#
# 원문 :  열심히 살아왔는데 지금 이 가슴 한달에 넘는 가격에 서민들은 죽어가는 현실입니다 라는 부디 힘을 마지막 않게 도와주세요
# 실제 요약문 : 도와주세요
# 예측 요약문 :  대한항공
#
#
# 원문 :  돈을 얼마나
# 실제 요약문 : 취소해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  또다시 대한항공 조현민의 갑질을 보니 속이 대한이란 쓰지 못하게 하고 조현민의 반드시 아직도 우리가 이런 세상에 살고 있다는 것이
# 실제 요약문 : 대한항공 조현민 전무 처벌 요구
# 예측 요약문 :  국회의원
#
#
# 원문 :  저희 나라 마스크 90 이상이 합니다 지금 마스크를 힘들고 넘게 마스크 자국민이 없는데 지금 마스크 해야 합니까 전면 주세요
# 실제 요약문 : 마스크
# 예측 요약문 :  국회의원
#
#
# 원문 :  처벌을 강력히 촉구합니다 저런 사건들이 일반인 10 구속 무전유죄 모두 유전무죄 맞습니다
# 실제 요약문 : 이명희 한진그룹 가족들 처벌
# 예측 요약문 :  국회의원
#
#
# 원문 :  노동 폭행을 당하는 우리 국민 구해주세요 또한 은혜로교회 수사를 요구합니다 수사 촉구 바라며 구해주세요
# 실제 요약문 : 우리 국민들을 구해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  남편 3번째 그것도 부인 수많은 피해를 입고 개미들 이리 저리 같은 버젓이 방송에 아니라고 그의 강력히 원합니다
# 실제 요약문 : 모두 반드시 방송퇴출
# 예측 요약문 :  자유한국당
#
#
# 원문 :  대한항공 조현민 대한 갑질을 처벌해주세요
# 실제 요약문 : 조현민 갑질을 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  제대로 국민에게 국회의원들 일은 하지 않고 일삼는 국민에게 주는 의원들 혈세 받을 권리가 있을까요 최저 지급해야 합니다
# 실제 요약문 : 국회의원 7530원 지급
# 예측 요약문 :  자유한국당
#
#
# 원문 :  정부는 도대체 무엇을 하고 있습니까 바뀌지 않는 수많은 선수들이 못하고 이용 당하고 있습니다 빙상연맹 회장 빙상연맹 부회장 임원 권력에 모두 하세요 공정하고 무너지고 있습니다 사태를 없습니다 나라입니까
# 실제 요약문 : 빙상연맹 부회장을 처벌하라 동의 해주세요 제발
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  사람이 것이 말이되냐 경찰들 것이 이런 약자들을 영구 한다 사퇴하라
# 실제 요약문 : 택시기사 경찰 제명하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한 여러가지 의혹들이 있습니다 누구보다 모범이 되어야 신속하게 의혹 없이 수사가 국민들에게 것으로 생각합니다
# 실제 요약문 : 이재명경기지사 진상규명 요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  아시다시피 신천지 때문에 나라가 되었습니다 그런데도 검찰은 제대로 수사를 하지 않습니다 윤석열 생각이 없는것 같습니다 한다고 생각합니다 추미애 강력하게 요청합니다
# 실제 요약문 : 강력하게 요청합니다
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  조두순이 무서워서 어디 있겠습니까 범죄를 고작 술을 사람들이
# 실제 요약문 : 조두순 출소 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  안녕하세요 저는 근무 20대 여성 입니다 현재 코로나 바이러스가 확산되고 있습니다 이에 모든 마스크를 있도록 해주셨으면 좋겠습니다 경우 보기 이유로 마스크를 있습니다 항공 미용실 있도록 해주셨으면 좋겠습니다 부탁드립니다
# 실제 요약문 : 코로나바이러스 모든 마스크 하도록 만들어주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  연합뉴스 폐지 삼성 국민의 눈이 되어야 언론에서 삼성과 국민을 기만하고 개인의 위해 국민이 아닌 삼성을 위해 폐지를 요청합니다 또한 이와 관련된 수사를 요청합니다
# 실제 요약문 : 연합뉴스 폐지 수사요청
# 예측 요약문 :  국회의원
#
#
# 원문 :  pc방 살인을 저지른 재수사 바랍니다
# 실제 요약문 : 동생 재수사 요청합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  관련된 조사 처벌을 원합니다 삼성은 언론을 통하여 기사 이나라의 국민을 개 돼지로 알고 언론을 언론은 국민을 아니면 말고 대한민국을 좀먹는 말로 생각합니다
# 실제 요약문 : 삼성의
# 예측 요약문 :  국회의원
#
#
# 원문 :  하는지 않습니다 아무런 안되고 학교에서 없습니다 그냥 반으로 같아요 제가 학생들을 같아요
# 실제 요약문 : 폐지해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  정말 그렇게 때리고 해도 그런데 사람에게 욕하고 해결 김성태 사람은 1년 때려도 흐지부지 아니라고 본다
# 실제 요약문 : 이명희 구속하라 lt 언제 gt
# 예측 요약문 :  국회의원
#
#
# 원문 :  kbs 수신료 강제 징수 반대 합니다
# 실제 요약문 : 납부거부
# 예측 요약문 :  국회의원
#
#
# 원문 :  진정 국민들을 위해 서서 국민들 않을까요 국회의원도 최저시급으로 계기가 되었으면 합니다
# 실제 요약문 : 국회의원 최저시급으로
# 예측 요약문 :  국회의원
#
#
# 원문 :  현재 가운데 난민에 인천 정부에서는 언론은 http news naver com read nhn mode lsd amp mid sec amp oid amp aid amp sid1 001 amp cafe 언론 하는 겁니까 이렇게 되면
# 실제 요약문 : 인천공항
# 예측 요약문 :  국회의원
#
#
# 원문 :  된다는 선수를 그런데 국회의원은 가장 많은 받는 바꾸고 싶은 유착 높은 국회의원의 선수를 혹은
# 실제 요약문 : 국회의원 선수 제한
# 예측 요약문 :  국회의원
#
#
# 원문 :  자유한국당 사립유치원 뇌물 남편 또한 같은 판결에 나도 진짜 다른 사람에게 누명씌워서 좋겠습니다 그래서 문제를 특검 또는 경찰 검찰이 같습니다
# 실제 요약문 : 자유한국당 대한
# 예측 요약문 :  자유한국당 매크로
#
#
# 원문 :  2년 어떻게 해서 국민들은 이해가 되질 형량이 어떤 공개 하시길 바랍니다
# 실제 요약문 : 유정호씨 너무 합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  2020 11 17 동시에 모든 거래가 되었습니다 되지 않고 않습니다 이로인해 말도안되는 국민들의 소중한 돈이 손해를 보고 있습니다 한국 아닙니다 엄청난 손해를 봤습니다 본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다
# 실제 요약문 : 한국 거래 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  12 수익을 위해 가까운 이는 보이고 이는 부정한 주식시장을 수익을 불법을 것으로 의심됩니다 이는 반드시 조사하여 다시는 이런일이 있습니다
# 실제 요약문 : 주가조작 조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민 대다수가 폐지를 원합니다 하루빨리 폐지해야 합니다 아무리 시장에서 것입니다
# 실제 요약문 : 하루빨리
# 예측 요약문 :  국회의원
#
#
# 원문 :  박수진 배용준 삼성병원 조사해 주세요 상황에 이들이 혜택을 유명 이유만으로 신생아 피해를 바로 적폐청산 아닐까요 이에 관련 sns를 볼때마다 정말 화가 납니다
# 실제 요약문 : 박수진 배용준
# 예측 요약문 :  자유한국당
#
#
# 원문 :  서울 매일 아침마다 사람들로 문제는 너무 것입니다 아침마다 10분 한다는게 너무 불편합니다 뿐만아니라 최근 있는데 거의 손을 합니다 부탁드립니다
# 실제 요약문 : 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  무참히 칼로 찔러 이유는 말도 안되고 평생 마음에 상처를 입고 살아 가해자 혼자 아니라는 말이 지금 있습니다 가해자 동생이 겁니다 관심이 필요합니다
# 실제 요약문 : 강서구 피시방 살인 사건 해야합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  링크를 영상을 보시면 하는 정도로 보입니다 의하면 경찰의 범죄의 앞에 사람은 아닌 똑같은 직무를 있어 다른 것은 말이 되지 않는다고 생각합니다 현명한 판단 부탁드립니다
# 실제 요약문 : 경찰 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  국민의 국민을 위해 검찰에 국민의 알권리를 무시하는 일삼고 있습니다 검찰과 원하는 정치 행태를 보이고 있습니다 국민을 위한 보도를 하지않고 검찰에 악의적 하는 더이상 수가 없습니다 이에 더이상 거부
# 실제 요약문 : kbs 거부합니다
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  물론 5 의 세금은 꼬박꼬박 엄청난 손실이 발생하고 있습니다 손실을 보는 것은 제가 하는 인한 피해를 보는 것은 국가의 필요하다고 봅니다 더군다나 엄청난 것으로 알고 있습니다 청원합니다
# 실제 요약문 : 바랍니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  같은 생각합니다 아니고 혜택이 아니고 정말 공평하게 내년
# 실제 요약문 : 내년 출산장려금 간절히 부탁드립니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  나라에 나라에 그럼 나라에 있으니 아니라 국민들 읽고 절대
# 실제 요약문 : 김종필 반대합니다
# 예측 요약문 :  대한항공
#
#
# 원문 :  온몸에 아마 봅니다 이것은 갑질 이상의 사람들에 대해 있도록 관련 비리가 없는지
# 실제 요약문 : 처벌
# 예측 요약문 :  국회의원
#
#
# 원문 :  아직도 우리나라 중국의 지속적으로 말도 안되는 국민들은 우리나라 지정해 국민들의 줄여주세요
# 실제 요약문 : 우리나라 지정해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  무엇을 일단 우리나라 바이오 알고 삼성이 조금 잘못이 우리나라를 그리고 개인 돈은 누가
# 실제 요약문 : 삼성바이오로직스 이게
# 예측 요약문 :  국회의원
#
#
# 원문 :
# 실제 요약문 : 나경원
# 예측 요약문 :  국회의원
#
#
# 원문 :  왜 세금으로 여성 성매매 사회 지원 그럼 일하는 사람을 자신이 돈이 선택을 하고 가정이 어려운 저는 인천시 성매매 여성 사회 지원 반대합니다
# 실제 요약문 : 인천시 여성 지원금 지급 반대
# 예측 요약문 :  국회의원
#
#
# 원문 :  이 우리는 돌려주세요
# 실제 요약문 : 세금
# 예측 요약문 :  국회의원
#
#
# 원문 :  내용에 초등 합니다 등교 있으며 했습니다 비해 마스크 힘들어하는 저학년 아이들을 먼저 입장에서는 상당히 불안합니다 청원드립니다
# 실제 요약문 : 유치원생
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한민국 국익에 해를 입히는 행동과 일삼는 모든 합니다
# 실제 요약문 : 나경원 올림픽 해임
# 예측 요약문 :  국회의원
#
#
# 원문 :  뉴스 국민들에게 희망을 지속적으로 성폭행 받고 조재범 코치를 또한 무지한
# 실제 요약문 : 심석희 조재범 코치
# 예측 요약문 :  대한항공
#
#
# 원문 :  국민세금으로 세비를 받고 있는 국회의원이 태극기 이제는 대통령을 향해 입에 명예를 훼손하고 국격을 일삼고 있습니다 세금으로 세비를 보수 떠나 정치판에서 주십시요
# 실제 요약문 : 의원직 박탈을 강력히 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  대구 사는 대한민국 국민 입니다 문재인 정부는 나은 대한민국을 위해 반드시 이재명 조폭 대해 진실을 밝혀주세요 그리고 엄벌하여 주세요 정치인 권력 돈 조폭 돈 들의 문재인 반드시 보여주세요
# 실제 요약문 : 이재명 은수미 수사 엄벌 촉구합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  조선일보는 국민을 있다 그리고 일부 그들의 각종 비리를 저지르고 있다 또한 일부 거짓 여론을 확대 있고 지역의 보호를 위해서 있다 심각한 조선일보를 언론
# 실제 요약문 : 조선일보 폐간 경영진 비리 조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  정말 대한민국의 국민으로서
# 실제 요약문 : 여상규 의원 더이상 없습니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  말도 안전하게 함께 할수 있도록 절대
# 실제 요약문 : 개고기 적극 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  있는 진짜 많이 이게 아니고 무슨 대통령님 제발 도로를 제가 너무
# 실제 요약문 : 경기도
# 예측 요약문 :  국회의원
#
#
# 원문 :  이번 고등학교 코로나 확진자 관련하여 학부모입니다 너무도 가고 싶은 하며 1년 없는데 너무 생각이 들어 눈물로 구제 방법을
# 실제 요약문 : 우리
# 예측 요약문 :  국회의원
#
#
# 원문 :  살고있는 입니다 말입니까 자라나는 아이들이 바라는 이제 얼마나 심각한데 아기들이 살기좋은 해주십시오 저희의 저희는 어디가서
# 실제 요약문 : 의료폐기물 반대
# 예측 요약문 :  국회의원
#
#
# 원문 :  대한항공 일가 조현아 조현민 자매가 보면 우리 사회에서 돈과 국민을 얼마나 보여주는 국민을 여기는 없습니다 최소한 대한항공의 대한이란 명칭을 하고 해서
# 실제 요약문 : 대한항공 태극마크
# 예측 요약문 :  국회의원
#
#
# 원문 :  1인 으로써 문재인 대통령님께서 광주 에서 세계 1위 등등 각종 위반 행동을 있는데요 철처히 세무조사 대해서 조사가 합니다 국민청원 부탁드립니다
# 실제 요약문 : 문재인 대통령님 세무조사
# 예측 요약문 :  국회의원
#
#
# 원문 :  문재인 대통령은 많은 사람으로 있다는 사실을 태영호 철저하게 수사하여
# 실제 요약문 : 태영호 구속 수사하라
# 예측 요약문 :  국회의원
#
#
# 원문 :  김기덕 조재현 처벌해 주세요
# 실제 요약문 : 김기덕 조재현 처벌
# 예측 요약문 :  자유한국당
#
#
# 원문 :  국민의 안전을 위해 일본 것을 청원합니다 일본 해당하는 이상으로 국민들을 보호해 주십시오 청원을 이유는 같습니다 이상 발생 위험 위험 폭행 위험 국민의 안전은 없습니다 감사합니다 국민
# 실제 요약문 : 지정 청원합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  처벌법을 제정해주세요
# 실제 요약문 : 강제개종목사 처벌해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  코로나 바이러스가 한국에서 주된 원인을 제공하고 그러한 사실을 국민들을 고통에 신천지 관련 전수조사 방역 치료 자가격리 생활비 지원금 모든 신천지에서 안하면 결국 국민들 세금으로 엄청난 비용이
# 실제 요약문 : 신천지 전수조사 주세요
# 예측 요약문 :  대한항공
#
#
# 원문 :  1년 전혀 방송 문재인은 정녕 수신료를
# 실제 요약문 : kbs 강제 수신료 징수
# 예측 요약문 :  대한항공
#
#
# 원문 :  지금 국회의원 연봉인상을 2019년 예산을 곳에서 한다고 알았습니다 국민들이 연봉 없다 하더니 연봉을 자기들 마음대로 거의 해야 하는 보입니다 차라리 돈으로 우리나라에 필요한 곳에
# 실제 요약문 : 국회의원 연봉 인상 반대합니다
# 예측 요약문 :  국회의원
#
#
# 원문 :  조현민이 대한항공 자녀의 신분을 이용하여 우리나라 국민들을 너무 수많은 분들이 너무 상처를 받았고 대부분의 국민들은 받았습니다 평등한 법이 해외로 시켜서 외국인이 못하게 해주세요
# 실제 요약문 : 미국인 조현민을 입국금지 시켜 주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  입고 뻔뻔하게 위증을 원합니다 바랍니다
# 실제 요약문 : 조여옥 대위 처벌
# 예측 요약문 :  국회의원
#
#
# 원문 :  아이들 문제 심각합니다 어제 사건은 아이들 학원 대책이 필요합니다 법적으로 대책을 않으면 아까운 아이들이 제발 대대적인 법을 세워주세요
# 실제 요약문 : 의무화 단속
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  너무나 많은 피해자가 한다면 피해자가 않을까요 하는지 국민들은 이해가 안갑니다 범죄를 위해서라도 우리가 직접 정보를 있도록 공개를 원합니다
# 실제 요약문 : 성범죄자 주소 해주세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  청원합니다
# 실제 요약문 : 국회의원 해외출장 전수조사 청원
# 예측 요약문 :  국회의원
#
#
# 원문 :  제한 나이 제한 횟수 제한 모든걸 제한을 지원 그렇게 제한을 두고 뭐가 합리적인 라는 않은 비용이 들고 그외 비용이 제한 나이제한 횟수 제한 애를 너무 제한을 없는 전혀 않습니다 하는게 웃기네요 제한 풀어주세요
# 실제 요약문 : 난임 제한 풀어주세요
# 예측 요약문 :  대한항공 의원
#
#
# 원문 :  연합뉴스 국민 세금 주지 마세요
# 실제 요약문 : 연합뉴스 국민 세금 마세요
# 예측 요약문 :  국회의원
#
#
# 원문 :  20대 국회의원 출장 을 전수조사하여 청와대 주시기 바랍니다
# 실제 요약문 : 국회의원 국외 출장 전수 조사
# 예측 요약문 :  국회의원
